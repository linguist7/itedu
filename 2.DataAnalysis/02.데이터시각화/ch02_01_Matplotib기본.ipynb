# %% [markdown]
# # **Ch02.01. Matplotlib 기본**
#
# ```
# 이 노트는 `Matplotlib Tutorial: 파이썬으로 데이터 시각화하기` 책을 바탕으로 공부하고 정리한 것임을 밝힙니다.
# ```
#
# * 책 소개
# >  [Matplotlib Tutorial: 파이썬으로 데이터 시각화하기](https://wikidocs.net/book/5011)
# >
#
#
# * 라이브러리 소개
#   > matplotlib

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## **01. 기본 사용**
# ---
#
# <p align='center'>
# <img src=https://wikidocs.net/images/page/92071/basics_00.png width=500>
# </p>

# %% [markdown]
# ### **| 기본 그래프 그리기**
#
#
# ```
# import matplotlib.pyplot as plt
#
# plt.plot([1, 2, 3, 4])
# plt.show()
# ```

# %%
plt.plot([1, 2, 3, 4])
plt.show()

# %% [markdown]
# ```
# plt.plot([1, 2, 3, 4], [1, 4, 9, 16])
# plt.show()
# ```

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16])
plt.show()

# %% [markdown]
# ### **| 스타일 지정하기**
#
#
# ```
# plt.plot([1, 2, 3, 4], [1, 4, 9, 16], 'ro')
# plt.axis([0, 6, 0, 20])
# plt.show()
# ```

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16], 'ro') #색상과 형태를 지정하는 포맷 문자열 (Format string)을 세번째 인자
#포맷 문자열 ‘ro’는 빨간색 (‘red’)의 원형 (‘o’) 마커를 의미합니다. 또한, 예를 들어 ‘b-‘는 파란색 (‘blue’)의 실선 (‘-‘)을 의미합니다.
plt.axis([0, 6, 0, 20]) # axis() 함수를 이용해서 축의 범위 [xmin, xmax, ymin, ymax]를 지정
# Out:
# (0.0, 6.0, 0.0, 20.0)

# %% [markdown]
# ### **| 여러 개의 그래프 그리기**
#
#
# ```
# # 200ms 간격으로 균일하게 샘플된 시간
# t = np.arange(0., 5., 0.2)
#
# # 빨간 대쉬, 파란 사각형, 녹색 삼각형
# plt.plot(t, t, 'r--', t, t**2, 'bs', t, t**3, 'g^')
# plt.show()
# ```

# %%
# 200ms 간격으로 균일하게 샘플된 시간
t = np.arange(0., 5., 0.2)

# 빨간 대쉬, 파란 사각형, 녹색 삼각형
plt.plot(t, t, 'r--', t, t**2, 'bs', t, t**3, 'g^')
plt.show()

# %% [markdown]
# ## **02. 숫자 입력하기**
#
# ---
#
# <p align='center'>
# <img src=https://wikidocs.net/images/page/137321/basic_plot_00.png width=500>
# </p>

# %% [markdown]
# ### **| 기본 사용**
#
#
# ```
# import matplotlib.pyplot as plt
#
# plt.plot([2, 3, 5, 10])
# plt.show()
# ```

# %%
plt.plot([2, 3, 5, 10])
plt.show()

# %% [markdown]
# ### **| x, y 값 입력**
#
#
# ```
# plt.plot([1, 2, 3, 4], [2, 3, 5, 10])
# plt.show()
# ```

# %%
plt.plot([1, 2, 3, 4], [2, 3, 5, 10])
plt.show()

# %% [markdown]
# ### **| 레이블이 있는 데이터 사용하기**
#
#
#
#
# ```
# data_dict = {'data_x': [1, 2, 3, 4, 5], 'data_y': [2, 3, 5, 10, 8]}
#
# plt.plot('data_x', 'data_y', data=data_dict)
# plt.show()
# ```

# %%
data_dict = {'data_x': [1, 2, 3, 4, 5], 'data_y': [2, 3, 5, 10, 8]}

plt.plot('data_x', 'data_y', data=data_dict) # plot() 함수에 데이터의 레이블 (딕셔너리의 키)을 입력해주고, data 파라미터에 딕셔너리를 지정해줍니다.
plt.show()

# %% [markdown]
# ## **03. 축 레이블 설정하기**
# ---
#
# <p align='center'>
# <img src=https://wikidocs.net/images/page/92081/set_label_00.png width=500>
# </p>

# %% [markdown]
# ### **| 기본 사용** plt.xlabel('축제목', labelpad=)
#
#
# ```
# import matplotlib.pyplot as plt
#
# plt.plot([1, 2, 3, 4], [1, 4, 9, 16])
# plt.xlabel('X-Label')
# plt.ylabel('Y-Label')
# plt.show()
# ```

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16])
plt.xlabel('X-Label')
plt.ylabel('Y-Label')
plt.show()

# %% [markdown]
# ### **| 여백 지정**
#
# ```
# plt.plot([1, 2, 3, 4], [2, 3, 5, 10])
# plt.xlabel('X-Axis', labelpad=15)
# plt.ylabel('Y-Axis', labelpad=20)
# plt.show()
# ```

# %%
plt.plot([1, 2, 3, 4], [2, 3, 5, 10])
plt.xlabel('X-Axis', labelpad=15)
plt.ylabel('Y-Axis', labelpad=20)
plt.show()

# %% [markdown]
# ### **| 폰트 설정하기**
#
#
# ```
# plt.plot([1, 2, 3, 4], [2, 3, 5, 10])
# plt.xlabel('X-Axis', labelpad=15, fontdict={'family': 'serif', 'color': 'b', 'weight': 'bold', 'size': 14})
# plt.ylabel('Y-Axis', labelpad=20, fontdict={'family': 'fantasy', 'color': 'deeppink', 'weight': 'normal', 'size': 'xx-large'})
# plt.show()
# ```

# %% [markdown]
#  fontdict 파라미터 옵션
# - family : 글꼴
# - color
# - weight : 투명도
# - size

# %%
plt.plot([1, 2, 3, 4], [2, 3, 5, 10])
plt.xlabel('X-Axis', labelpad=15, fontdict={'family': 'fantasy', 'color': 'b', 'weight': 'normal', 'size': 14})
plt.ylabel('Y-Axis', labelpad=20, fontdict={'family': 'serif', 'color': 'deeppink', 'weight': 'bold', 'size': 'xx-large'})
plt.show()

# %% [markdown]
# ```
# font1 = {'family': 'serif',
#          'color': 'b',
#          'weight': 'bold',
#          'size': 14
#          }
#
# font2 = {'family': 'fantasy',
#          'color': 'deeppink',
#          'weight': 'normal',
#          'size': 'xx-large'
#          }
#
# plt.plot([1, 2, 3, 4], [2, 3, 5, 10])
# plt.xlabel('X-Axis', labelpad=15, fontdict=font1)
# plt.ylabel('Y-Axis', labelpad=20, fontdict=font2)
# plt.show()
# ```

# %%
font1 = {'family': 'serif',
         'color': 'b',
         'weight': 'bold',
         'size': 14
         }

font2 = {'family': 'fantasy',
         'color': 'deeppink',
         'weight': 'normal',
         'size': 'xx-large'
         }

plt.plot([1, 2, 3, 4], [2, 3, 5, 10])
plt.xlabel('X-Axis', labelpad=15, fontdict=font1)
plt.ylabel('Y-Axis', labelpad=20, fontdict=font2)
plt.show()

# %% [markdown]
# ### **| 위치 지정하기**
#
#
# `xlabel()` 함수의 `loc` 파라미터는 X축 레이블의 위치를 지정합니다. `({‘left’, ‘center’, ‘right’})`
#
# `ylabel()` 함수의 `loc` 파라미터는 Y축 레이블의 위치를 지정합니다. `({‘bottom’, ‘center’, ‘top’})`
#
#
# ```
# plt.plot([1, 2, 3, 4], [2, 3, 5, 10])
# plt.xlabel('X-Axis', loc='right')
# plt.ylabel('Y-Axis', loc='top')
# plt.show()
# ```

# %%
plt.plot([1, 2, 3, 4], [2, 3, 5, 10])
plt.xlabel('X-Axis', loc='right')
plt.ylabel('Y-Axis', loc='top')
plt.show()

# %% [markdown]
# ## **04. 범례 표시하기**
# ---
#
# <p align='center'>
# <img src=https://wikidocs.net/images/page/137778/set_legend_00.png width=500>
# </p>

# %% [markdown]
# ### **| 기본 사용** - label='제목'& legend(loc=, ncol=)
#
# ```
# import matplotlib.pyplot as plt
#
# plt.plot([1, 2, 3, 4], [2, 3, 5, 10], label='Price ($)')
# plt.xlabel('X-Axis')
# plt.ylabel('Y-Axis')
# plt.legend()
#
# plt.show()
# ```

# %%
plt.plot([1, 2, 3, 4], [2, 3, 5, 10], label='Price ($)')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.legend()

plt.show()

# %% [markdown]
# ### **| 위치 지정하기**
#
#
#
# ```
# plt.plot([1, 2, 3, 4], [2, 3, 5, 10], label='Price ($)')
# plt.xlabel('X-Axis')
# plt.ylabel('Y-Axis')
# # plt.legend(loc=(0.0, 0.0))
# # plt.legend(loc=(0.5, 0.5))
# plt.legend(loc=(1.0, 1.0))
#
# plt.show()
# ```

# %%
plt.plot([1, 2, 3, 4], [2, 3, 5, 10], label='Price ($)')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
#plt.legend(loc=(0.0, 0.0))
plt.legend(loc=(0.5, 0.5))
#plt.legend(loc=(1.0, 1.0))

# %% [markdown]
# ```
# plt.plot([1, 2, 3, 4], [2, 3, 5, 10], label='Price ($)')
# plt.xlabel('X-Axis')
# plt.ylabel('Y-Axis')
# plt.legend(loc='lower right')
#
# plt.show()
# ```

# %%
plt.plot([1, 2, 3, 4], [2, 3, 5, 10], label='Price ($)')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.legend(loc='lower right')

plt.show()

# %% [markdown]
# ### **| 열 개수 지정하기**
#
#
# ```
# plt.plot([1, 2, 3, 4], [2, 3, 5, 10], label='Price ($)')
# plt.plot([1, 2, 3, 4], [3, 5, 9, 7], label='Demand (#)')
# plt.xlabel('X-Axis')
# plt.ylabel('Y-Axis')
# # plt.legend(loc='best')          # ncol = 1
# plt.legend(loc='best', ncol=2)    # ncol = 2
#
# plt.show()
# ```

# %%
plt.plot([1, 2, 3, 4], [2, 3, 5, 10], label='Price ($)')
plt.plot([1, 2, 3, 4], [3, 5, 9, 7], label='Demand (#)')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
# plt.legend(loc='best')          # ncol = 1   
plt.legend(loc='best', ncol=2)    # ncol = 2   가로로 몇개 표시할지    #legen --- 범례 위치조정

plt.show()

# %% [markdown]
# ### **| 폰트 크기 지정하기**
#
#
#
# ```
# plt.plot([1, 2, 3, 4], [2, 3, 5, 10], label='Price ($)')
# plt.plot([1, 2, 3, 4], [3, 5, 9, 7], label='Demand (#)')
# plt.xlabel('X-Axis')
# plt.ylabel('Y-Axis')
# # plt.legend(loc='best')
# plt.legend(loc='best', ncol=2, fontsize=14)
#
# plt.show()
# ```

# %%
plt.plot([1, 2, 3, 4], [2, 3, 5, 10], label='Price ($)')
plt.plot([1, 2, 3, 4], [3, 5, 9, 7], label='Demand (#)')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
# plt.legend(loc='best')
plt.legend(loc='best', ncol=2, fontsize=14)   

plt.show()

# %% [markdown]
# ### **| 범례 테두리 꾸미기**
#
#
#
# ```
# plt.plot([1, 2, 3, 4], [2, 3, 5, 10], label='Price ($)')
# plt.plot([1, 2, 3, 4], [3, 5, 9, 7], label='Demand (#)')
# plt.xlabel('X-Axis')
# plt.ylabel('Y-Axis')
# # plt.legend(loc='best')
# plt.legend(loc='best', ncol=2, fontsize=14, frameon=True, shadow=True)
#
# plt.show()
# ```

# %%
plt.plot([1, 2, 3, 4], [2, 3, 5, 10], label='Price ($)')
plt.plot([1, 2, 3, 4], [3, 5, 9, 7], label='Demand (#)')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
# plt.legend(loc='best')
plt.legend(loc='best', ncol=2, fontsize=14, frameon=False, shadow=True) # frameon 테투리      shadow 그림자

plt.show()

# %% [markdown]
# ## **05. 축 범위 지정하기**
# ---
#
# <p align='center'>
# <img src=https://wikidocs.net/images/page/92082/axis_range_00.png width=500>
# </p>

# %% [markdown]
# ### **| 기본 사용 - `xlim(), ylim()`**
#
#
#
# ```
# import matplotlib.pyplot as plt
#
# plt.plot([1, 2, 3, 4], [2, 3, 5, 10])
# plt.xlabel('X-Axis')
# plt.ylabel('Y-Axis')
# plt.xlim([0, 5])      # X축의 범위: [xmin, xmax]
# plt.ylim([0, 20])     # Y축의 범위: [ymin, ymax]
#
# plt.show()
# ```

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [2, 3, 5, 10])
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.xlim([0, 5])      # X축의 범위: [xmin, xmax]
plt.ylim([0, 20])     # Y축의 범위: [ymin, ymax]

plt.show()

# %% [markdown]
# ### **| 기본 사용: `axis()`**
#
#
#
#
# ```
# plt.plot([1, 2, 3, 4], [2, 3, 5, 10])
# plt.xlabel('X-Axis')
# plt.ylabel('Y-Axis')
# plt.axis([0, 5, 0, 20])  # X, Y축의 범위: [xmin, xmax, ymin, ymax]
#
# plt.show()
# ```

# %%
plt.plot([1, 2, 3, 4], [2, 3, 5, 10])
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.axis([0, 5, 0, 20])  # X, Y축의 범위: [xmin, xmax, ymin, ymax]

plt.show()

# %% [markdown]
# ### **| 옵션 지정하기**
#
# ```
# 'on' | 'off' | 'equal' | 'scaled' | 'tight' | 'auto' | 'normal' | 'image' | 'square'
# ```
# ```
# plt.plot([1, 2, 3, 4], [2, 3, 5, 10])
# plt.xlabel('X-Axis')
# plt.ylabel('Y-Axis')
# # plt.axis('square')
# plt.axis('scaled')
#
# plt.show()
# ```

# %%
plt.plot([1, 2, 3, 4], [2, 3, 5, 10])
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.axis('equal') #off 선만 남게만듬   equal -도 만듬
#plt.axis('scaled')

plt.show()

# %% [markdown]
# ### **| 축 범위 얻기**
#
#
# ```
# plt.plot([1, 2, 3, 4], [2, 3, 5, 10])
# plt.xlabel('X-Axis')
# plt.ylabel('Y-Axis')
#
# x_range, y_range = plt.xlim(), plt.ylim()
# print(x_range, y_range)
#
# axis_range = plt.axis('scaled')
# print(axis_range)
#
# plt.show()
# ```

# %%
plt.plot([1, 2, 3, 4], [2, 3, 5, 10])
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')

x_range, y_range = plt.xlim(), plt.ylim()
print(x_range, y_range)

axis_range = plt.axis('scaled')
print(axis_range)

plt.show()
# Out:
# (0.85, 4.15) (1.6, 10.4)
# (0.85, 4.15, 1.6, 10.4)

# %% [markdown]
# ## **06. 선 종류 지정하기**
# ---
#
# <p align='center'>
# <img src=https://wikidocs.net/images/page/137791/set_linestyle_00.png width=500>
# </p>

# %% [markdown]
# ### **| 기본 사용**
#
#
# | 표현 | 종류 |
# |--|--|
# |`-`  | Solid |
# | `--` |Dashed|
# |`:`|Dotted|
# |`-.` |Dash-dot|
#
# ```
# import matplotlib.pyplot as plt
#
# plt.plot([1, 2, 3], [4, 4, 4], '-', color='C0', label='Solid')
# plt.plot([1, 2, 3], [3, 3, 3], '--', color='C0', label='Dashed')
# plt.plot([1, 2, 3], [2, 2, 2], ':', color='C0', label='Dotted')
# plt.plot([1, 2, 3], [1, 1, 1], '-.', color='C0', label='Dash-dot')
# plt.xlabel('X-Axis')
# plt.ylabel('Y-Axis')
# plt.axis([0.8, 3.2, 0.5, 5.0])
# plt.legend(loc='upper right', ncol=4)
# plt.show()
# ```

# %%
plt.plot([1, 2, 3], [4, 4, 4], '-', color='C0', label='Solid')
plt.plot([1, 2, 3], [3, 3, 3], '--', color='C0', label='Dashed')
plt.plot([1, 2, 3], [2, 2, 2], ':', color='C2', label='Dotted')
plt.plot([1, 2, 3], [1, 1, 1], '-.', color='C1', label='Dash-dot')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.axis([0.8, 3.2, 0.5, 5.0])        #축범위
plt.legend(loc='upper right', ncol=4)
plt.show()

# %% [markdown]
# ### **| linestyle 지정하기**
#
#
# | 표현 | 종류 |
# |--|--|
# |`solid`  | Solid |
# | `dashed` |Dashed|
# |`dotted`|Dotted|
# |`dashdot` | Dash-dot|
#
# ```
# plt.plot([1, 2, 3], [4, 4, 4], linestyle='solid', color='C0', label="'solid'")
# plt.plot([1, 2, 3], [3, 3, 3], linestyle='dashed', color='C0', label="'dashed'")
# plt.plot([1, 2, 3], [2, 2, 2], linestyle='dotted', color='C0', label="'dotted'")
# plt.plot([1, 2, 3], [1, 1, 1], linestyle='dashdot', color='C0', label="'dashdot'")
# plt.xlabel('X-Axis')
# plt.ylabel('Y-Axis')
# plt.axis([0.8, 3.2, 0.5, 5.0])
# plt.legend(loc='upper right', ncol=4)
# plt.tight_layout()
# plt.show()
# ```

# %%
plt.plot([1, 2, 3], [4, 4, 4], linestyle='solid', color='C0', label="'solid'")
plt.plot([1, 2, 3], [3, 3, 3], linestyle='dashed', color='C0', label="'dashed'")
plt.plot([1, 2, 3], [2, 2, 2], linestyle='dotted', color='C0', label="'dotted'")
plt.plot([1, 2, 3], [1, 1, 1], linestyle='dashdot', color='C0', label="'dashdot'")
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.axis([0.8, 3.2, 0.5, 5.0])
plt.legend(loc='upper right', ncol=2)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### **| 튜플 사용하기**
#
#
# ```
# plt.plot([1, 2, 3], [4, 4, 4], linestyle=(0, (1, 1)), color='C0', label='(0, (1, 1))')
# plt.plot([1, 2, 3], [3, 3, 3], linestyle=(0, (1, 5)), color='C0', label='(0, (1, 5))')
# plt.plot([1, 2, 3], [2, 2, 2], linestyle=(0, (5, 1)), color='C0', label='(0, (5, 1))')
# plt.plot([1, 2, 3], [1, 1, 1], linestyle=(0, (3, 5, 1, 5)), color='C0', label='(0, (3, 5, 1, 5))')
# plt.xlabel('X-Axis')
# plt.ylabel('Y-Axis')
# plt.axis([0.8, 3.2, 0.5, 5.0])
# plt.legend(loc='upper right', ncol=2)
# plt.tight_layout()
# plt.show()
# ```

# %%
plt.plot([1, 2, 3], [4, 4, 4], linestyle=(0, (1, 1)), color='C0', label='(0, (1, 1))')
plt.plot([1, 2, 3], [3, 3, 3], linestyle=(0, (1, 5)), color='C0', label='(0, (1, 5))')
plt.plot([1, 2, 3], [2, 2, 2], linestyle=(0, (5, 1)), color='C0', label='(0, (5, 1))')
plt.plot([1, 2, 3], [1, 1, 1], linestyle=(0, (3, 5, 1, 5)), color='C0', label='(0, (3, 5, 1, 5))')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.axis([0.8, 3.2, 0.5, 5.0])
plt.legend(loc='upper right', ncol=2)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### **| 선 끝 모양 지정하기**
#
#
#
#
#
# ```
# import matplotlib.pyplot as plt
#
# plt.plot([1, 2, 3], [4, 4, 4], linestyle='solid', linewidth=10,
#       solid_capstyle='butt', color='C0', label='solid+butt')
# plt.plot([1, 2, 3], [3, 3, 3], linestyle='solid', linewidth=10,
#       solid_capstyle='round', color='C0', label='solid+round')
#
# plt.plot([1, 2, 3], [2, 2, 2], linestyle='dashed', linewidth=10,
#       dash_capstyle='butt', color='C1', label='dashed+butt')
# plt.plot([1, 2, 3], [1, 1, 1], linestyle='dashed', linewidth=10,
#       dash_capstyle='round', color='C1', label='dashed+round')
#
#
# plt.xlabel('X-Axis')
# plt.ylabel('Y-Axis')
# plt.axis([0.8, 3.2, 0.5, 5.0])
# plt.legend(loc='upper right', ncol=2)
# plt.tight_layout()
# plt.show()
# ```

# %%
plt.plot([1, 2, 3], [4, 4, 4], linestyle='solid', linewidth=5,
      solid_capstyle='butt', color='C0', label='solid+butt')
plt.plot([1, 2, 3], [3, 3, 3], linestyle='solid', linewidth=10,
      solid_capstyle='round', color='C0', label='solid+round')

plt.plot([1, 2, 3], [2, 2, 2], linestyle='dashed', linewidth=10,
      dash_capstyle='butt', color='C1', label='dashed+butt')
plt.plot([1, 2, 3], [1, 1, 1], linestyle='dashed', linewidth=10,
      dash_capstyle='round', color='C1', label='dashed+round')                   ########## butt 네모                    round 둥글게              dashed 점선


plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.axis([0.8, 3.2, 0.5, 5.0])
plt.legend(loc='upper right', ncol=2)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## **07. 마커 지정하기**
# ---
#
# <p align='center'>
# <img src=https://wikidocs.net/images/page/92083/set_marker_00.png width=500>
# </p>

# %% [markdown]
# ### **| 기본 사용**
#
#
# ```
# import matplotlib.pyplot as plt
#
# plt.plot([1, 2, 3, 4], [2, 3, 5, 10], 'bo')
# plt.xlabel('X-Axis')
# plt.ylabel('Y-Axis')
# plt.show()
# ```

# %%
plt.plot([1, 2, 3, 4], [2, 3, 5, 10], 'bo')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.show()

# %% [markdown]
# ### **| 선/마커 동시에 나타내기**
#
#
# ```
# # plt.plot([1, 2, 3, 4], [2, 3, 5, 10], 'bo-')    # 파란색 + 마커 + 실선
# plt.plot([1, 2, 3, 4], [2, 3, 5, 10], 'bo--')     # 파란색 + 마커 + 점선
# plt.xlabel('X-Axis')
# plt.ylabel('Y-Axis')
# plt.show()
# ```

# %%
plt.plot([1, 2, 3, 4], [2, 3, 5, 10], 'bo-') 
#plt.plot([1, 2, 3, 4], [2, 3, 5, 10], 'bo--')     # 파란색 + 마커 + 점선
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.show()

# %% [markdown]
# ### **| 선/마커 표시 형식**
#
# | 표현 | 종류 |
# |--|--|
# |`b`  | blue markers with default shape |
# | `ro` |red circles|
# |`g-`|green solid line|
# |`k^` | balck triangle_up markers connected by a dotted line|
#
#
# ```
# # plt.plot([1, 2, 3, 4], [2, 3, 5, 10], 'bo-')    # 파란색 + 마커 + 실선
# plt.plot([1, 2, 3, 4], [2, 3, 5, 10], 'bo--')     # 파란색 + 마커 + 점선
# plt.xlabel('X-Axis')
# plt.ylabel('Y-Axis')
# plt.show()
# ```

# %%
# plt.plot([1, 2, 3, 4], [2, 3, 5, 10], 'bo-')    # 파란색 + 마커 + 실선
plt.plot([1, 2, 3, 4], [2, 3, 5, 10], 'bo--')     # 파란색 + 마커 + 점선
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.show()

# %% [markdown]
# ### **| marker 파라미터 사용하기**
#
# ```
# plt.plot([4, 5, 6], marker="H")
# plt.plot([3, 4, 5], marker="d")
# plt.plot([2, 3, 4], marker="x")
# plt.plot([1, 2, 3], marker=11)
# plt.plot([0, 1, 2], marker='$Z$')
# plt.show()
# ```

# %%
plt.plot([4, 5, 6], marker=8)
plt.plot([3, 4, 5], marker="d")
plt.plot([2, 3, 4], marker="x")
plt.plot([1, 2, 3], marker=11)
plt.plot([0, 1, 2], marker='$h$')
plt.show()

# %% [markdown]
# ---
# ## **08. 색상 지정하기**
# ---
#
# <p align='center'>
# <img src=https://wikidocs.net/images/page/92085/set_color_00.png width=500>
# </p>

# %% [markdown]
# ### **| 포맷 문자열 사용하기**
#
#
# ```
# import matplotlib.pyplot as plt
#
# plt.plot([1, 2, 3, 4], [2.0, 3.0, 5.0, 10.0], 'r')
# plt.plot([1, 2, 3, 4], [2.0, 2.8, 4.3, 6.5], 'g')
# plt.plot([1, 2, 3, 4], [2.0, 2.5, 3.3, 4.5], 'b')
# plt.xlabel('X-Axis')
# plt.ylabel('Y-Axis')
#
# plt.show()
# ```

# %%
plt.plot([1, 2, 3, 4], [2.0, 3.0, 5.0, 10.0], 'r')
plt.plot([1, 2, 3, 4], [2.0, 2.8, 4.3, 6.5], 'g')
plt.plot([1, 2, 3, 4], [2.0, 2.5, 3.3, 4.5], 'b')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')

plt.show()

# %% [markdown]
# ### **| `color` 키워드 인자 사용하기**
#
#
# ```
# plt.plot([1, 2, 3, 4], [2.0, 3.0, 5.0, 10.0], color='limegreen')
# plt.plot([1, 2, 3, 4], [2.0, 2.8, 4.3, 6.5], color='violet')
# plt.plot([1, 2, 3, 4], [2.0, 2.5, 3.3, 4.5], color='dodgerblue')
# plt.xlabel('X-Axis')
# plt.ylabel('Y-Axis')
#
# plt.show()
# ```

# %% [markdown]
# ### **| Hex code 사용하기**
#
#
#
#
# ```
# plt.plot([1, 2, 3, 4], [2, 3, 5, 10], color='#e35f62',
#          marker='o', linestyle='--')
# plt.xlabel('X-Axis')
# plt.ylabel('Y-Axis')
#
# plt.show()
# ```

# %%
plt.plot([1, 2, 3, 4], [2, 3, 5, 10], color='#e35f62',
         linestyle='--', marker='o')          #순서 상관x
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')

plt.show()

# %% [markdown]
# ### **| Matplotlib 색상들**

# %% [markdown]
# * **Cycler 색상**
#
#
# <p align='center'>
# <img src=https://wikidocs.net/images/page/92085/set_color_06.png width=300>
# </p>

# %% [markdown]
# * **기본 색상**
#
#
# <p align='center'>
# <img src=https://wikidocs.net/images/page/92085/set_color_04.PNG width=500>
# </p>

# %% [markdown]
# * **Tableau 색상**
#
#
# <p align='center'>
# <img src=https://wikidocs.net/images/page/92085/set_color_07.PNG width=450>
# </p>

# %% [markdown]
# * **CSS 색상**
# <p align='center'>
# <img src=https://wikidocs.net/images/page/92085/set_color_05.PNG width=550>
# </p>

# %% [markdown]
# ## **09. 그래프 영역 채우기**
# ---
#
# <p align='center'>
# <img src=https://wikidocs.net/images/page/92086/fill_region_00.png width=500>
# </p>

# %% [markdown]
# ### **| 기본 사용 - fill_between()**
#
#
# ```
# import matplotlib.pyplot as plt
#
# x = [1, 2, 3, 4]
# y = [2, 3, 5, 10]
#
# plt.plot(x, y)
# plt.xlabel('X-Axis')
# plt.ylabel('Y-Axis')
# plt.fill_between(x[1:3], y[1:3], alpha=0.5)
#
# plt.show()
# ```

# %%
x = [1, 2, 3, 4]
y = [2, 3, 5, 10]

plt.plot(x, y)
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.fill_between(x[0:3], y[0:3], alpha=0.5)  #       fill_between(x어레이 슬라이싱, y어레이 슬라이싱, 진하기)

plt.show()

# %% [markdown]
# ### **| 기본 사용 - fill_betweenx()**
#
#
#
# ```
# x = [1, 2, 3, 4]
# y = [2, 3, 5, 10]
#
# plt.plot(x, y)
# plt.xlabel('X-Axis')
# plt.ylabel('Y-Axis')
# plt.fill_betweenx(y[2:4], x[2:4], alpha=0.5)
#
# plt.show()
# ```

# %%
x = [1, 2, 3, 4]
y = [2, 3, 5, 10]

plt.plot(x, y)
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.fill_betweenx(y[1:3], x[1:3], alpha=0.5)  #바깥쪽

plt.show()

# %% [markdown]
# ### **| 두 그래프 사이 영역 채우기**
#
#
# ```
# x = [1, 2, 3, 4]
# y1 = [2, 3, 5, 10]
# y2 = [1, 2, 4, 8]
#
# plt.plot(x, y1)
# plt.plot(x, y2)
# plt.xlabel('X-Axis')
# plt.ylabel('Y-Axis')
# plt.fill_between(x[1:3], y1[1:3], y2[1:3], color='lightgray', alpha=0.5)
#
# plt.show()
# ```

# %%
x = [1, 2, 3, 4]
y1 = [2, 3, 5, 10]
y2 = [1, 2, 4, 8]

plt.plot(x, y1)
plt.plot(x, y2)
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.fill_between(x[1:3], y1[1:3], y2[1:3], color='lightgray', alpha=0.5)

plt.show()

# %% [markdown]
# ### **| 다각형 영역 채우기 - fill()**
#
# ```
# x = [1, 2, 3, 4]
# y1 = [2, 3, 5, 10]
# y2 = [1, 2, 4, 8]
#
# plt.plot(x, y1)
# plt.plot(x, y2)
# plt.xlabel('X-Axis')
# plt.ylabel('Y-Axis')
# plt.fill([1.9, 1.9, 3.1, 3.1], [1.0, 4.0, 6.0, 3.0], color='lightgray', alpha=0.5)
#
# plt.show()
# ```

# %%
x = [1, 2, 3, 4]
y1 = [2, 3, 5, 10]
y2 = [1, 2, 4, 8]

plt.plot(x, y1)
plt.plot(x, y2)
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.fill([1.9, 1.9, 3.1, 3.1], [1.0, 4.0, 6.0, 3.0], color='lightgray', alpha=0.5)

plt.show()

# %% [markdown]
# ## **10. 축 스케일 지정하기**
# ---
#
# <p align='center'>
# <img src=https://wikidocs.net/images/page/137913/axis_scale_00.png width=500>
# </p>

# %% [markdown]
# ### **| X축 스케일 지정하기**
#
#
# ```
# import matplotlib.pyplot as plt
# import numpy as np
#
# x = np.linspace(-10, 10, 100)
# y = x ** 3
#
# plt.plot(x, y)
# plt.xscale('symlog')
#
# plt.show()
# ```

# %%
x = np.linspace(-10, 10, 100)
y = x ** 3

plt.plot(x, y)
plt.xscale('linear') #xscale(), yscale() 함수를 사용해서 그래프의 축 스케일을 다양하게 지정할 수 있습니다. 축은 기본적으로 ‘linear’ 스케일로 표시되지만 ‘log’, ‘symlog’, ‘logit’으로 변경할 수 있습니다.

plt.show()

# %% [markdown]
# ### **| Y축 스케일 지정하기**
#
# ```
# x = np.linspace(0, 5, 100)
# y = np.exp(x)
#
# plt.plot(x, y)
# # plt.yscale('linear')
# plt.yscale('log')
#
# plt.show()
# ```

# %%
x = np.linspace(0, 5, 100)
y = np.exp(x)

plt.plot(x, y)
# plt.yscale('linear')
plt.yscale('log')

plt.show()

# %% [markdown]
# ## **11. 여러 곡선 그리기**
#
# ---
#
# <p align='center'>
# <img src=https://wikidocs.net/images/page/92087/multiple_curves_00.png width=500>
# </p>

# %% [markdown]
# ### **| 기본사용**
#
#
#
# ```
# import matplotlib.pyplot as plt
# import numpy as np
#
# x = np.arange(0, 2, 0.2)
#
# plt.plot(x, x, 'r--', x, x**2, 'bo', x, x**3, 'g-.')
# plt.show()
# ```

# %%
x = np.arange(0, 2, 0.2)

plt.plot(x, x, 'r--', x, x**2, 'bo', x, x**3, 'g-.')
plt.show()

# %% [markdown]
# ### **| 스타일 지정하기**
#
#
# ```
# x = np.arange(0, 2, 0.2)
#
# plt.plot(x, x, 'bo')
# plt.plot(x, x**2, color='#e35f62', marker='*', linewidth=2)
# plt.plot(x, x**3, color='forestgreen', marker='^', markersize=9)
# plt.show()
# ```

# %% [markdown]
# ## **12. 그리드 설정하기**
# ---
#
# <p align='center'>
# <img src=https://wikidocs.net/images/page/92088/set_grid_00.png width=500>
# </p>

# %% [markdown]
# ### **| 기본사용** - grid(True, axis='')
#
# ```
# import matplotlib.pyplot as plt
# import numpy as np
#
# x = np.arange(0, 2, 0.2)
#
# plt.plot(x, x, 'bo')
# plt.plot(x, x**2, color='#e35f62', marker='*', linewidth=2)
# plt.plot(x, x**3, color='springgreen', marker='^', markersize=9)
# plt.grid(True)
#
# plt.show()
# ```

# %%
x = np.arange(0, 2, 0.2)

plt.plot(x, x, 'bo')
plt.plot(x, x**2, color='#e35f62', marker='*', linewidth=2)
plt.plot(x, x**3, color='springgreen', marker='^', markersize=9)           
plt.grid(True)

plt.show()

# %% [markdown]
# ### **| 축 지정하기**
#
#
#
#
# ```
# x = np.arange(0, 2, 0.2)
#
# plt.plot(x, x, 'bo')
# plt.plot(x, x**2, color='#e35f62', marker='*', linewidth=2)
# plt.plot(x, x**3, color='forestgreen', marker='^', markersize=9)
# plt.grid(True, axis='y')
#
# plt.show()
# ```

# %%
x = np.arange(0, 2, 0.2)

plt.plot(x, x, 'bo')
plt.plot(x, x**2, color='#e35f62', marker='*', linewidth=2)
plt.plot(x, x**3, color='forestgreen', marker='^', markersize=9)
plt.grid(True, axis='x')

plt.show()

# %% [markdown]
# ### **| 스타일 설정하기**
#
#
# ```
# x = np.arange(0, 2, 0.2)
#
# plt.plot(x, x, 'bo')
# plt.plot(x, x**2, color='#e35f62', marker='*', linewidth=2)
# plt.plot(x, x**3, color='springgreen', marker='^', markersize=9)
# plt.grid(True, axis='y', color='red', alpha=0.5, linestyle='--')
#
# plt.show()
# ```

# %% [markdown]
# ## **13. 눈금 표시하기**
# ---
#
# <p align='center'>
# <img src=https://wikidocs.net/images/page/92089/set_ticks_00.png width=500>
# </p>

# %% [markdown]
# ### **| 기본사용** - (x)tichks(np.arage())
#
#
# ```
# import numpy as np
#
# x = np.arange(0, 2, 0.2)
#
# plt.plot(x, x, 'bo')
# plt.plot(x, x**2, color='#e35f62', marker='*', linewidth=2)
# plt.plot(x, x**3, color='forestgreen', marker='^', markersize=9)
# plt.xticks([0, 1, 2])
# plt.yticks(np.arange(1, 6))
#
# plt.show()
# ```

# %%
x = np.arange(0, 2, 0.2)

plt.plot(x, x, 'bo')
plt.plot(x, x**2, color='#e35f62', marker='*', linewidth=2)
plt.plot(x, x**3, color='forestgreen', marker='^', markersize=9)
plt.xticks([0, 1, 2])
plt.yticks(np.arange(1, 6))

plt.show()

# %% [markdown]
# ### **| 눈금 레이블 지정하기**
#
#
# ```
# x = np.arange(0, 2, 0.2)
#
# plt.plot(x, x, 'bo')
# plt.plot(x, x**2, color='#e35f62', marker='*', linewidth=2)
# plt.plot(x, x**3, color='springgreen', marker='^', markersize=9)
# plt.xticks(np.arange(0, 2, 0.2), labels=['Jan', '', 'Feb', '', 'Mar', '', 'May', '', 'June', '', 'July'])
# plt.yticks(np.arange(0, 7), ('0', '1GB', '2GB', '3GB', '4GB', '5GB', '6GB'))
#
# plt.show()
# ```

# %%
plt.plot(x, x, 'bo')
plt.plot(x, x**2, color='#e35f62', marker='*', linewidth=2)
plt.plot(x, x**3, color='springgreen', marker='^', markersize=9)
plt.xticks(np.arange(0, 2, 0.2), labels=['Jan', '', 'Feb', '', 'Mar', '', 'May', '', 'June', '', 'July'])
plt.yticks(np.arange(0, 7), ('0', '1GB', '2GB', '3GB', '4GB', '5GB', '6GB'))

plt.show()

# %% [markdown]
# ### **| 눈금 스타일 설정하기** -tick_params(axis='y', 옵션)
#
#
# ```
# x = np.arange(0, 2, 0.2)
#
# plt.plot(x, x, 'bo')
# plt.plot(x, x**2, color='#e35f62', marker='*', linewidth=2)
# plt.plot(x, x**3, color='springgreen', marker='^', markersize=9)
# plt.xticks(np.arange(0, 2, 0.2), labels=['Jan', '', 'Feb', '', 'Mar', '', 'May', '', 'June', '', 'July'])
# plt.yticks(np.arange(0, 7), ('0', '1GB', '2GB', '3GB', '4GB', '5GB', '6GB'))
#
# plt.tick_params(axis='x', direction='in', length=3, pad=6, labelsize=14, labelcolor='green', top=True)
# plt.tick_params(axis='y', direction='inout', length=10, pad=15, labelsize=12, width=2, color='r')
#
# plt.show()
# ```

# %%
plt.plot(x, x, 'bo')
plt.plot(x, x**2, color='#e35f62', marker='*', linewidth=2)
plt.plot(x, x**3, color='springgreen', marker='^', markersize=9)
plt.xticks(np.arange(0, 2, 0.2), labels=['Jan', '', 'Feb', '', 'Mar', '', 'May', '', 'June', '', 'July'])
plt.yticks(np.arange(0, 7), ('0', '1GB', '2GB', '3GB', '4GB', '5GB', '6GB'))

plt.tick_params(axis='x', direction='inout', length=3, pad=6, labelsize=14, labelcolor='green', top=False)
plt.tick_params(axis='y', direction='out', length=40, pad=0, labelsize=10, width=4, color='r')      # 안쪽과 바깥쪽, 길이, 레이블 위치 얼만큼 떨어질지, 글자크기, 굵기,  top 위쪽에도 눈금선을 둘것인가

plt.show()

# %% [markdown]
# ## **14. 타이틀 설정하기**
# ---
#
# <p align='center'>
# <img src=https://wikidocs.net/images/page/92090/set_title_00.png width=450>
# </p>

# %% [markdown]
# ### **| 기본사용** - title('제목')
#
#
#
# ```
# import matplotlib.pyplot as plt
# import numpy as np
#
# x = np.arange(0, 2, 0.2)
#
# plt.plot(x, x, 'bo')
# plt.plot(x, x**2, color='#e35f62', marker='*', linewidth=2)
# plt.plot(x, x**3, color='forestgreen', marker='^', markersize=9)
#
# plt.tick_params(axis='both', direction='in', length=3, pad=6, labelsize=14)
# plt.title('Graph Title')
#
# plt.show()
# ```

# %%
x = np.arange(0, 2, 0.2)

plt.plot(x, x, 'bo')
plt.plot(x, x**2, color='#e35f62', marker='*', linewidth=2)
plt.plot(x, x**3, color='forestgreen', marker='^', markersize=9)

plt.tick_params(axis='both', direction='in', length=3, pad=6, labelsize=14)
plt.title('Graph Title')

plt.show()

# %% [markdown]
# ### **| 위치와 오프셋 지정하기**
#
#
# ```
# x = np.arange(0, 2, 0.2)
#
# plt.plot(x, x, 'bo')
# plt.plot(x, x**2, color='#e35f62', marker='*', linewidth=2)
# plt.plot(x, x**3, color='forestgreen', marker='^', markersize=9)
#
# plt.tick_params(axis='both', direction='in', length=3, pad=6, labelsize=14)
# plt.title('Graph Title', loc='right', pad=20)
#
# plt.show()
# ```

# %% [markdown]
# ### **| 폰트 지정하기**
#
#
#
#
#
#
# ```
# x = np.arange(0, 2, 0.2)
#
# plt.plot(x, x, 'bo')
# plt.plot(x, x**2, color='#e35f62', marker='*', linewidth=2)
# plt.plot(x, x**3, color='forestgreen', marker='^', markersize=9)
#
# plt.tick_params(axis='both', direction='in', length=3, pad=6, labelsize=14)
# plt.title('Graph Title', loc='right', pad=20)
#
# title_font = {
#     'fontsize': 16,
#     'fontweight': 'bold'
# }
# plt.title('Graph Title', fontdict=title_font, loc='left', pad=20)
#
# plt.show()
# ```

# %% [markdown]
# ### **| 타이틀 얻기**
#
#
#
# ```
# x = np.arange(0, 2, 0.2)
#
# plt.plot(x, x, 'bo')
# plt.plot(x, x**2, color='#e35f62', marker='*', linewidth=2)
# plt.plot(x, x**3, color='forestgreen', marker='^', markersize=9)
#
# plt.tick_params(axis='both', direction='in', length=3, pad=6, labelsize=14)
# title_right = plt.title('Graph Title', loc='right', pad=20)
#
# title_font = {
#     'fontsize': 16,
#     'fontweight': 'bold'
# }
# title_left = plt.title('Graph Title', fontdict=title_font, loc='left', pad=20)
#
# print(title_left.get_position())
# print(title_left.get_text())
#
# print(title_right.get_position())
# print(title_right.get_text())
#
# plt.show()
# ```

# %%
x = np.arange(0, 2, 0.2)

plt.plot(x, x, 'bo')
plt.plot(x, x**2, color='#e35f62', marker='*', linewidth=2)
plt.plot(x, x**3, color='forestgreen', marker='^', markersize=9)

plt.tick_params(axis='both', direction='in', length=3, pad=6, labelsize=14)
title_right = plt.title('Graph Title', loc='right', pad=20)

title_font = {
    'fontsize': 16,
    'fontweight': 'bold'
}
title_left = plt.title('Graph Title', fontdict=title_font, loc='left', pad=20)

print(title_left.get_position())
print(title_left.get_text())

print(title_right.get_position())
print(title_right.get_text())

plt.show()
# Out:
# (0.0, 1.0)
# Graph Title
# (1.0, 1.0)
# Graph Title

# %% [markdown]
# ## **29. 이미지 저장하기**
# ---
#
# <p align='center'>
# <img src=https://wikidocs.net/images/page/92090/set_title_00.png width=450>
# </p>

# %% [markdown]
# ### **| 기본사용** -plt.savefig('파일이름', dpi=해상도, facecolor=배경색, edgecolor=테투리색)
#
#
#
# ```
# import numpy as np
# import matplotlib.pyplot as plt
#
# x1 = np.linspace(0.0, 5.0)
# x2 = np.linspace(0.0, 2.0)
#
# y1 = np.cos(2 * np.pi * x1) * np.exp(-x1)
# y2 = np.cos(2 * np.pi * x2)
#
# plt.subplot(2, 1, 1)                # nrows=2, ncols=1, index=1
# plt.plot(x1, y1, 'o-')
# plt.title('1st Graph')
# plt.ylabel('Damped oscillation')
#
# plt.subplot(2, 1, 2)                # nrows=2, ncols=1, index=2
# plt.plot(x2, y2, '.-')
# plt.title('2nd Graph')
# plt.xlabel('time (s)')
# plt.ylabel('Undamped')
#
# plt.tight_layout()
# # plt.show()
# plt.savefig('savefig_default.png')
# ```

# %%
x1 = np.linspace(0.0, 5.0)
x2 = np.linspace(0.0, 2.0)
x1
# Out:
# array([0.        , 0.10204082, 0.20408163, 0.30612245, 0.40816327,
#        0.51020408, 0.6122449 , 0.71428571, 0.81632653, 0.91836735,
#        1.02040816, 1.12244898, 1.2244898 , 1.32653061, 1.42857143,
#        1.53061224, 1.63265306, 1.73469388, 1.83673469, 1.93877551,
#        2.04081633, 2.14285714, 2.24489796, 2.34693878, 2.44897959,
#        2.55102041, 2.65306122, 2.75510204, 2.85714286, 2.95918367,
#        3.06122449, 3.16326531, 3.26530612, 3.36734694, 3.46938776,
#        3.57142857, 3.67346939, 3.7755102 , 3.87755102, 3.97959184,
#        4.08163265, 4.18367347, 4.28571429, 4.3877551 , 4.48979592,
#        4.59183673, 4.69387755, 4.79591837, 4.89795918, 5.        ])

# %%
x1 = np.linspace(0.0, 5.0)
x2 = np.linspace(0.0, 2.0)

y1 = np.cos(2 * np.pi * x1) * np.exp(-x1)
y2 = np.cos(2 * np.pi * x2)

plt.subplot(2, 1, 1)                # nrows=2, ncols=1, index=1
plt.plot(x1, y1, 'o-')
plt.title('1st Graph')
plt.ylabel('Damped oscillation')

plt.subplot(2, 1, 2)                # nrows=2, ncols=1, index=2
plt.plot(x2, y2, '.-')
plt.title('2nd Graph')
plt.xlabel('time (s)')
plt.ylabel('Undamped')

plt.tight_layout()
# plt.show()
plt.savefig('savefig_default.png')

# %% [markdown]
# ## 문제풀이
# ---

# %% [markdown]
# ####**예제 01**
#
# 아래의 플롯과 최대한 비슷하게 그리고 `ch0201_01`로 저장하세요
#
#
# <p align='left'>
# <img src=https://github.com/yebiny/Lecture-EDA-basic/blob/main/imgs/07-1.PNG?raw=true width=400>
# </p>

# %%
import numpy as np
import matplotlib.pyplot as plt

x1 = [1, 2, 3, 4, 5]
y1 = [1, 2, 4, 8, 9]

x2 = [1, 2, 3, 4, 5]
y2 = [10, 5, 4, 2, 1]

plt.yticks([2, 4, 6, 8, 10])
plt.plot(x2, y2, 'o-', markersize=2)
plt.plot(x1, y1, 'o-')
plt.show()
plt.savefig('ch0201_01')

# %% [markdown]
# ####**예제 02**
#
# 아래의 플롯과 최대한 비슷하게 그리고 `ch0201_02`로 저장하세요
#
# <p align='left'>
# <img src=https://github.com/yebiny/Lecture-EDA-basic/blob/main/imgs/07-2.PNG?raw=true width=400>
# </p>

# %%
x1 = [1, 2, 3, 4, 5]
y1 = [1, 2, 4, 8, 9]

x2 = [1, 2, 3, 4, 5]
y2 = [10, 5, 4, 2, 1]
plt.yticks([2, 4, 6, 8, 10])

plt.plot(x2, y2, 'o-', label='Uncertainty')
plt.plot(x1, y1, 'o-', label='Skill')
plt.legend(loc='best', ncol=2, fontsize=14, frameon=True, shadow=True)
plt.fill_between(x1[1:4], y1[1:4], y2[1:4], color='springgreen', alpha=0.5)

plt.show()
plt.savefig('ch0201_02')

# %% [markdown]
# ####**예제 03**
#
# 아래의 플롯과 최대한 비슷하게 그리고 `ch0201_03`로 저장하세요
#
#
# <p align='left'>
# <img src=https://github.com/yebiny/Lecture-EDA-basic/blob/main/imgs/07-3.PNG?raw=true width=400>
# </p>

# %%
x1 = [1, 2, 3, 4, 5]
y1 = [1, 2, 4, 8, 9]

x2 = [1, 2, 3, 4, 5]
y2 = [10, 5, 4, 2, 1]
plt.axis([0, 6, 0, 14])

plt.plot(x2, y2, 'o-', label='Uncertainty')
plt.plot(x1, y1, 'o-', label='Skill')
plt.legend(loc='best', ncol=2, fontsize=14, frameon=True, shadow=True)

plt.xlabel('X-Axis', fontdict={'family': 'serif', 'color': 'C9', 'weight': 'bold', 'size': 'xx-large'})
plt.ylabel('Y-Axis', fontdict={'family': 'serif', 'color': 'C9', 'weight': 'bold', 'size': 'xx-large'})

plt.show()
plt.savefig('ch0201_03')

# %% [markdown]
# ####**예제 04**
#
# 아래의 플롯과 최대한 비슷하게 그리고 `ch0201_04`로 저장하세요
#
# <p align='left'>
# <img src=https://github.com/yebiny/Lecture-EDA-basic/blob/main/imgs/07-4.PNG?raw=true width=400>
# </p>

# %%
x1 = [1, 2, 3, 4, 5]
y1 = [1, 2, 4, 8, 9]

x2 = [1, 2, 3, 4, 5]
y2 = [10, 5, 4, 2, 1]

plt.plot(x2, y2, 'o-', label='Uncertainty', color='C0')
plt.plot(x1, y1, 'o-', label='Skill', color='C6')
plt.legend(loc='upper center', ncol=1)

plt.title('My plot', fontdict={'weight': 'bold',  'size':15})
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')

plt.grid(True)

plt.show()
plt.savefig('ch0201_04')

# %% [markdown]
# ####**예제 05**
#
# 아래의 플롯과 최대한 비슷하게 그리고 `ch0201_05`로 저장하세요
#
#
# <p align='left'>
# <img src=https://github.com/yebiny/Lecture-EDA-basic/blob/main/imgs/07-5.PNG?raw=true width=400>
# </p>

# %%
x1 = [1, 2, 3, 4, 5]
y1 = [1, 2, 4, 8, 9]

x2 = [1, 2, 3, 4, 5]
y2 = [10, 5, 4, 2, 1]

plt.plot(x2, y2, label='Uncertainty', color='C0', linestyle='dashed', linewidth=10)
plt.plot(x1, y1, marker='*', markersize=20, label='Skill', linestyle='solid', linewidth=5, color='C6')
plt.legend(loc='upper center', ncol=1)

plt.title('My plot', loc='left', fontdict={'weight': 'bold',  'size':15})
plt.xlabel('X-Axis',  fontdict={'family': 'fantasy', 'color': 'black', 'weight': 'bold', 'size': 'xx-large'})
plt.ylabel('Y-Axis',  fontdict={'family': 'fantasy', 'color': 'black', 'weight': 'bold', 'size': 'xx-large'})

plt.tick_params(axis='x', direction='out', length=10, pad=2, labelsize=14, width=5, labelcolor='C')
plt.tick_params(axis='y', direction='out', length=10, pad=2, labelsize=10, width=5, labelcolor='C') 

plt.grid(True, axis='y')

plt.show()
plt.savefig('ch0201_05')

# %% [markdown]
# ####**예제 06**
#
# 본인 스타일 대로 데이터를 잘 나타내도록 그림을 그리고 `ch0201_06`으로 저장하세요.

# %%
x1 = [1, 2, 3, 4, 5]
y1 = [1, 2, 4, 8, 9]

x2 = [1, 2, 3, 4, 5]
y2 = [10, 5, 4, 2, 1]

plt.plot(x2, y2, label='Uncertainty', color='C9', linestyle='solid', solid_capstyle='round', linewidth=5)
plt.plot(x1, y1, marker='x', markersize=20, label='Skill', linestyle='dashdot', linewidth=5, color='C3')

plt.legend(loc='best', ncol=2, fontsize=14, frameon=True, shadow=True) #범례 위치 및 스타일

plt.axis([0, 5, 0, 12])  # X, Y축의 범위: [xmin, xmax, ymin, ymax]


plt.title('My plot', loc='right', fontdict={'weight': 'light',  'size':15}) #제목


plt.xlabel('X-Axis',  fontdict={'family': 'fantasy', 'color': 'black', 'weight': 'bold', 'size': 'xx-large'})
plt.ylabel('Y-Axis',  fontdict={'family': 'fantasy', 'color': 'black', 'weight': 'bold', 'size': 'xx-large'})  #축


plt.xticks(np.arange(0, 7), labels=['A', '', 'B', '', 'C', '', 'D'])
plt.yticks(np.arange(0, 11), ('0kg','', '1kg','', '2kg','', '3kg','', '4kg','', '5kg','', '6kg'))        #눈금 레이블 지정

plt.tick_params(axis='x', direction='inout', length=10, pad=10, labelsize=15, width=1, labelcolor='C8')   #눈금 스타일
plt.tick_params(axis='y', direction='inout', length=10, pad=10, labelsize=15, width=1, labelcolor='C5') 

plt.grid(True, axis='x')

plt.show()
plt.savefig('ch0201_06')
