# %% [markdown]
# # ch05.09. 사이킷런 실습 - 회귀분석
#
# ---
# * 날짜:
# * 이름:
#
# ## 학습내용
#     - 사이킷런을 이용해 여러가지 회귀 모델을 사용한다.
#     - 회귀 성능 지표에 대해 이해한다.
#     - 회귀 분석 결과를 시각화 한다.

# %% [markdown]
# ```
# import numpy as np
# import pandas as pd
# import seaborn as sns
# import matplotlib.pyplot as plt
# ```

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## 단순 회귀 분석
# ---

# %% [markdown]
# ### **| 데이터 처리**

# %% [markdown]
# #### **주택 데이터 EDA**
#
# [https://archive.ics.uci.edu/ml/datasets/Housing](https://archive.ics.uci.edu/ml/datasets/Housing)
#
#
# <pre>
# 01. CRIM     도시의 인당 범죄율
# 02. ZN       2만 5,0000평방 피트가 넘는 주택 비율
# 03. INDUS    도시에서 소매 업종이 아닌 지역 비율
# 04. CHAS     찰스 강 인접 여부(강 주변=1, 그외=0)
# 05. NOX      일산화질소 농도(10ppm당)
# 06. RM       주택의 평균 방 개수
# 07. AGE      1940년 이전에 지어진 자가 주택 비율
# 08. DIS      다섯 개의 보스턴 고용 센터까지 가중치가 적용된 거리
# 09. RAD      방사형으로 뻗은 고속도로까지 접근성 지수
# 10. TAX      10만 달러당 재산세율
# 11. PTRATIO  도시의 학생-교사 비율
# 12. B        1000(Bk - 0.63)^2 도시의 아프리카계 미국인 비율
# 13. LSTAT    저소득층 비율
# 14. MEDV     자가 주택의 중간가격 (단위 $1000s)
# </pre>
#
# ```
# import pandas as pd
#
# df = pd.read_csv('https://raw.githubusercontent.com/rasbt/'
#                  'python-machine-learning-book-3rd-edition/'
#                  'master/ch10/housing.data.txt',
#                  header=None,
#                  sep='\s+')
#
# df.columns = ['CRIM', 'ZN', 'INDUS', 'CHAS',
#               'NOX', 'RM', 'AGE', 'DIS', 'RAD',
#               'TAX', 'PTRATIO', 'B', 'LSTAT', 'MEDV']
# ```

# %%
import pandas as pd
import numpy as np

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split


cols, norm = False, True

df = pd.read_csv('https://raw.githubusercontent.com/rasbt/'
               'python-machine-learning-book-3rd-edition/'
               'master/ch10/housing.data.txt',
               header=None,
               sep='\s+')
df.columns = ['CRIM', 'ZN', 'INDUS', 'CHAS', 
              'NOX', 'RM', 'AGE', 'DIS', 'RAD', 
              'TAX', 'PTRATIO', 'B', 'LSTAT', 'MEDV']
print(df.shape)
if cols:
  X = df[cols].values
else:
  X = df.drop(['MEDV'], axis=1)
y = df['MEDV'].values
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2, random_state=1)

if norm:
    sc_x = StandardScaler()
    sc_y = StandardScaler()
    #스케일링 파라미터(평균, 분산) -> 트레이닝 셋
    #적용은 -> 트레이닝, 테스트
    #fit :학습(파라미터 찾기)
    #fit_transform : 학습과 동시에 파라미터 적용
    #transform : 파라미터 적용

    # trainset: 학습+변환
    #sc_x.fit(X_train)
    #sc_y.fit( np.expand_dims(y_train, 1) )

    X_train = sc_x.fit_transform(X_train)
    y_train = sc_y.fit_transform( np.expand_dims(y_train, 1) ).flatten()
    
    # testset : 변환만
    X_test = sc_x.transform(X_test)
    y_test = sc_y.transform( np.expand_dims(y_test, 1) ).flatten()
  return X_train, X_test, y_train, y_test

# %% [markdown]
# * 데이터 불러오기 및 기본 shape 확인

# %%
df = pd.read_csv('https://raw.githubusercontent.com/rasbt/'
                 'python-machine-learning-book-3rd-edition/'
                 'master/ch10/housing.data.txt',
                 header=None,
                 sep='\s+')

df.columns = ['CRIM', 'ZN', 'INDUS', 'CHAS', 
              'NOX', 'RM', 'AGE', 'DIS', 'RAD', 
              'TAX', 'PTRATIO', 'B', 'LSTAT', 'MEDV']

print(df.shape)
df.head(10)
# Out:
# (506, 14)
#       CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575   65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421   78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185   61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998   45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147   54.2  6.0622    3  222.0
# 5  0.02985   0.0   2.18     0  0.458  6.430   58.7  6.0622    3  222.0
# 6  0.08829  12.5   7.87     0  0.524  6.012   66.6  5.5605    5  311.0
# 7  0.14455  12.5   7.87     0  0.524  6.172   96.1  5.9505    5  311.0
# 8  0.21124  12.5   7.87     0  0.524  5.631  100.0  6.0821    5  311.0
# 9  0.17004  12.5   7.87     0  0.524  6.004   85.9  6.5921    5  311.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2
# 5     18.7  394.12   5.21  28.7
# 6     15.2  395.60  12.43  22.9
# 7     15.2  396.90  19.15  27.1
# 8     15.2  386.63  29.93  16.5
# 9     15.2  386.71  17.10  18.9

# %% [markdown]
# * 각 속성별 기본 정보 확인

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    int64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    int64
#  9   TAX      506 non-null    float64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    506 non-null    float64
#  13  MEDV     506 non-null    float64
# dtypes: float64(12), int64(2)
# memory usage: 55.5 KB

# %% [markdown]
# * 속성별 고유값 확인

# %%
for col in df.columns:
  n_unique = len(df[col].unique())
  print(col, n_unique)
# Out:
# CRIM 504
# ZN 26
# INDUS 76
# CHAS 2
# NOX 81
# RM 446
# AGE 356
# DIS 412
# RAD 9
# TAX 66
# PTRATIO 46
# B 357
# LSTAT 455
# MEDV 229

# %% [markdown]
# * 속성별 분포 시각화

# %%
fig, axes = plt.subplots(2, 7, figsize=(20,6))
axes = axes.flatten()
for col, ax in zip(df.columns, axes):
  sns.histplot(data=df, x=col, ax=ax)
plt.show()

# %% [markdown]
# * 속성간 상관계수 시각화

# %%
sns.heatmap(df.corr(), annot=True, vmax=1, vmin=-1, cmap='coolwarm')

# %% [markdown]
# * 모든 속성간 산점도 그리기

# %%
sns.pairplot(data=df.sample(100))

# %% [markdown]
# #### **데이터 전처리**

# %% [markdown]
# * 넘파이 배열로 변환

# %%
#df.values #넘파이 배열 변환
# 단순회귀 X:RM y: MEDV
X = df['RM'].values
y = df['MEDV'].values
#방법1
X = X.reshape(-1,1)
#방법2
#X = df[['RM']].values
X.shape, y.shape
# 모델 라이브러리에서의 암묵적인 룰
# 인풋 X는 2차 텐서(행렬)
# 아웃풋 y는 1차 텐서(벡터) / 단, 세개이상 카테고리면 행렬
# Out:
# ((506, 1), (506,))

# %% [markdown]
# * 데이터 분할 (테스트 비율 0.2)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    test_size=0.2,
                                                    random_state=1)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((404, 1), (102, 1), (404,), (102,))

# %% [markdown]
# * 스케일링 - 정규화 진행

# %%
from sklearn.preprocessing import StandardScaler


sc_x = StandardScaler() #x에 대한 정규화 mean, std가 정해지지 않음
sc_y = StandardScaler() #y에 대한 정규화 mean, std가 정해지지 않음
sc_x.fit(X_train) #인풋 X_train에 대한 mean, std 정해주기
sc_y.fit(y_train.reshape(-1,1)) #아웃풋 y_train에 대한 mean, std 정해주기
#fit 함수의 인풋은 2차 텐서

#sc_x 함수 : 데이터가 들어오면 x - x_train의 평균을 빼주고 / std_xtrain 분산으로 나눠준다.
# Out:
# StandardScaler()

# %% [markdown]
# * 훈련 데이터 정규화

# %%
X_train = sc_x.fit_transform(X_train)
y_train = sc_y.fit_transform(y_train.reshape(-1,1)).flatten()
X_train.shape, y_train.shape
# Out:
# ((404, 13), (404,))

# %% [markdown]
# * 테스트 데이터 정규화

# %%
X_test = sc_x.fit_transform(X_test)
y_test = sc_y.fit_transform(y_test.reshape(-1,1)).flatten()
X_test.shape, y_test.shape
# Out:
# ((102, 13), (102,))

# %% [markdown]
# ### **| 모델링**

# %% [markdown]
# #### **직접 만든 회귀 클래스 사용**

# %% [markdown]
# * 클래스 구현

# %%
class LinearRegressionGD():
  def __init__(self, lr=0.001, random_state=1):
    self.lr=lr
    self.seed = np.random.RandomState(random_state)

  def init_weights(self, X):
    self.w = self.seed.normal(loc=0.0, scale = 0.01, size=1+X.shape[1])
  
  def model(self, X):
    '''
    X : (n_samples, n_features)
    w : (n_features+1)
    
    return : (n_samples, )
    '''
    return np.dot(X, self.w[:-1])+self.w[-1]

  def predict(self, X):
    return np.where(self.model(X) >= 0.5, 1, 0) 

  def loss(self, y, y_hat):
    return 1/2 * ( (y-y_hat)**2 )
    
  def evaluate(self, X, y):
    y_hat = self.model(X) # 예측
    loss = ( self.loss(y,y_hat).sum() ) / len(y) # 손실 평균
    return loss

  def fit(self, X, y, epochs=10, show_params=False):

    self.init_weights(X) # 가중치 초기화
    self.history=dict(loss=[]) # history 초기화

    for epoch in range(epochs):
      # 최적화
      y_hat = self.model(X)
      self.w[:-1]+= self.lr * np.dot(X.T , (y-y_hat))
      self.w[-1] += self.lr * np.sum(y-y_hat)
      
      # 평가
      loss = self.evaluate(X, y)
      self.history['loss'].append(loss)
      print(f'[Epoch {epoch}] loss: {np.round(loss,2)}')
      if show_params: print(self.w)

  def draw_dflow(self, X, y, title='', figsize=(8,4)):
    y_hat = self.model(X)
    plt.figure(figsize=figsize)
    plt.title(title)
    plt.plot(y, label='y', marker='o')
    plt.plot(y_hat, label='$\hat{y}$', marker='.', linestyle='--')
    plt.legend()
    plt.show()

  def draw_lcurve(self, title='', figsize=(8,4)):
    plt.figure(figsize=figsize)
    plt.title(title)
    plt.plot(self.history['loss'], label='loss', marker='o')
    plt.xlabel('epoch')
    plt.legend()
    plt.show()

# %% [markdown]
# * 모델 로드 및 학습

# %%
model = LinearRegressionGD()
history = model.fit(X_train, y_train, epochs=20)
# Out:
# [Epoch 0] loss: 0.35
# [Epoch 1] loss: 0.3
# [Epoch 2] loss: 0.28
# [Epoch 3] loss: 0.28
# [Epoch 4] loss: 0.28
# [Epoch 5] loss: 0.28
# [Epoch 6] loss: 0.28
# [Epoch 7] loss: 0.27
# [Epoch 8] loss: 0.27
# [Epoch 9] loss: 0.27
# [Epoch 10] loss: 0.27
# [Epoch 11] loss: 0.27
# [Epoch 12] loss: 0.27
# [Epoch 13] loss: 0.27
# [Epoch 14] loss: 0.27
# [Epoch 15] loss: 0.27
# [Epoch 16] loss: 0.27
# [Epoch 17] loss: 0.27
# [Epoch 18] loss: 0.27
# [Epoch 19] loss: 0.27

# %% [markdown]
# * 학습곡선 그리기

# %%
model.draw_lcurve()

# %% [markdown]
# * 값 비교

# %%
print('성능: ', model.evaluate(X_train, y_train))
model.draw_dflow(X_test, y_test, figsize=(16,4))
# Out:
# 성능:  0.27490410225215317

# %% [markdown]
# * 기울기와 절편 구하기
#
# \begin{align}
# \hat{y} = wx+b
# \end{align}

# %%
w = model.w[0]
b = model.w[1]
print(f'기울기: {w:.3f}, 절편:{b:.3f}')

# MEDV 주택가격 = w(0.671) * 주택의 평균개수 + 0
# Out:
# 기울기: 0.671, 절편:-0.000

# %% [markdown]
# * 회귀선 시각화

# %%
plt.scatter(X_train, y_train             , label='trainset'    , c='dodgerblue', edgecolor='k')
plt.scatter(X_test, y_test             , label='testset'    , c='limegreen', edgecolor='k')
plt.plot(X_train, 0.671*X_train,                label='linear', color='r', linestyle=':')    
#X_every = np.arange(-4,4,0.1).reshape(-1,1)
#plt.plot(X_every, model.predict(X_every), label='linear', color='r', linestyle=':')    

plt.xlabel('Average number of rooms [RM] (standardized)')
plt.ylabel('Price in $1000s [MEDV] (standardized)')
plt.legend()
plt.show()

# %% [markdown]
# #### **사이킷런으로 추정**

# %% [markdown]
# * 모델 로드 및 학습

# %%
from sklearn.linear_model import *
linear = LinearRegression() # 모델 클래스 가져오기
linear.fit(X_train, y_train) # 학습
# Out:
# LinearRegression()

# %% [markdown]
# * 기울기와 절편 구하기
#
# \begin{align}
# \hat{y} = wx+b
# \end{align}

# %%
w = linear.coef_[0] # 계수 = 가중치(weight)
b = linear.intercept_ # 절편 = 편향(bias)
print(f'기울기: {w:.3f}, 절편:{b:.3f}')
# Out:
# 기울기: 0.671, 절편:0.000

# %% [markdown]
# * 회귀선 시각화

# %%
plt.scatter(X_train, y_train             , label='trainset'    , c='dodgerblue', edgecolor='k')
plt.scatter(X_test, y_test             , label='testset'    , c='limegreen', edgecolor='k')
plt.plot(X_train, 0.671*X_train,                label='linear', color='r', linestyle=':')    
#X_every = np.arange(-4,4,0.1).reshape(-1,1)
#plt.plot(X_every, model.predict(X_every), label='linear', color='r', linestyle=':')    

plt.xlabel('Average number of rooms [RM] (standardized)')
plt.ylabel('Price in $1000s [MEDV] (standardized)')
plt.legend()
plt.show()

# %% [markdown]
# #### **RANSAC을 사용한 안정된 회귀모델 훈련**
#
# - RANSAC (RANdom SAmple Consensus)
# - 이상치를 효율적으로 다루는 알고리즘
# - 이상치를 제거하는 대신 정상치(inlier) 라는 일부 데이터로 회귀 모델을 훈련
#
# ```
# 1. 랜덤하게 일부 샘플을 정상치로 선택하여 모델 훈련
# 2. 훈련된 모델에서 다른 모든 포인트를 테스트하여 사용자가 입력한 허용 오차 안에 속한 포인트를 정상치에 추가
# 3. 모든 정상치를 사용하여 모델을 재훈련
# 4. 훈련된 모델과 정상치 간의 오차 추정
# 5. 성능이 사용자가 지정한 임계 값에 도달하거나 지정된 반복 횟수에 도달하면 알고리즘 종료
# ```

# %% [markdown]
# * 모델 로드 및 훈련

# %%
ransac = RANSACRegressor(LinearRegression(), # 사용할 모델
                         max_trials=100, # 최대 반복 횟수 
                         min_samples=50, # 랜덤하게 선택할 샘플의 최소 개수
                         loss='squared_error', #오차제곱,  절대값(absolut_error)
                         random_state=1
                         )

ransac.fit(X_train, y_train)
# Out:
# RANSACRegressor(base_estimator=LinearRegression(), loss='squared_error',
#                 min_samples=50, random_state=1)

# %% [markdown]
# * 학습 파라미터 확인

# %%
w = ransac.estimator_.coef_[0] # 계수 = 가중치(weight)
b = ransac.estimator_.intercept_ # 절편 = 편향(bias)
print(f'기울기: {w:.3f}, 절편:{b:.3f}')
# Out:
# 기울기: 0.708, 절편:0.041

# %% [markdown]
# * 정상치와 이상치 구분

# %%
y_linear_pred = linear.predict(X_test)
y_ransac_pred = ransac.predict(X_test)

print( np.mean(( y_test-y_linear_pred)**2  ) )
print( np.mean(( y_test-y_ransac_pred)**2  ) )
# Out:
# 0.4059098934088812
# 0.4009519683352657

# %%
inlier_mask = ransac.inlier_mask_ # 정상치 데이터 마스크
outlier_mask = np.logical_not(ransac.inlier_mask_) # 이상치 데이터 마스크
inlier_mask.shape, outlier_mask.shape
# Out:
# ((404,), (404,))

# %% [markdown]
# * 정상치와 이상치 데이터 시각화

# %%
plt.scatter(X_train[inlier_mask], y_train[inlier_mask]             , label='inlier'    , c='dodgerblue', edgecolor='k')
plt.scatter(X_train[outlier_mask], y_train[outlier_mask]             , label='outliner'    , c='limegreen', edgecolor='k')
plt.plot(X_train, 0.671*X_train,                label='linear', color='r', linestyle=':')    
#X_every = np.arange(-4,4,0.1).reshape(-1,1)
#plt.plot(X_every, model.predict(X_every), label='linear', color='r', linestyle=':')    

plt.xlabel('Average number of rooms [RM] (standardized)')
plt.ylabel('Price in $1000s [MEDV] (standardized)')
plt.legend()
plt.show()

# %% [markdown]
# ### **| 회귀 성능 지표**

# %% [markdown]
# * 성능지표 함수 임포트

# %%
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

# %% [markdown]
# * 성능 확인을 위한 y 예측값 불러오기

# %%
y_test.shape, y_linear_pred.shape
# Out:
# ((102,), (102,))

# %% [markdown]
# #### **MSE (Mean Squared Error, 평균 제곱 오차)**
#
# \begin{split}
# \frac{1}{n} \sum^n_{i=1}(y_i - \hat{y_i})^2
# \end{split}

# %%
mean_squared_error(y_test, y_linear_pred)
# Out:
# 0.4059098934088812

# %% [markdown]
# #### **RMSE (Root Mean Squared Error, 제곱근 평균 제곱 오차)**
#
# \begin{split}
# \sqrt{\frac{1}{n} \sum^n_{i=1}(y_i - \hat{y_i})^2}
# \end{split}

# %%
np.sqrt(mean_squared_error(y_test, y_linear_pred))
# Out:
# 0.6371105817743739

# %% [markdown]
# #### **MAE (Mean Absolute Error, 평균 절대 오차)**
#
# \begin{split}
# \frac{1}{n} \sum^n_{i=1}|y_i - \hat{y_i}|
# \end{split}

# %%
mean_absolute_error(y_test, y_linear_pred)
# Out:
# 0.4793490542043092

# %% [markdown]
# #### **NMAE (Noramlized Mean Absolute Error, 정규화된 평균 절대 오차)**
#
# \begin{split}
# \frac{MAE}{\frac{1}{n} \sum^n_{i=1}|y_i|}
# \end{split}

# %%
mean_absolute_error(y_test, y_linear_pred) / np.mean(np.abs(y_test))
# Out:
# 0.6890648265839221

# %% [markdown]
# #### **MAPE (Mean Absolute Percentage Error, 평균 절대 백분율 오차)**
#
# \begin{split}
# \frac{1}{n} \sum^n_{i=1} |\frac{y_i-\hat{y_i}}{y_i}| × 100 \
# \end{split}

# %%
np.mean(np.abs((y_test-y_linear_pred) / y_test)) * 100
# Out:
# 213.53004541981892

# %% [markdown]
# #### **SSE (Explained sum of squares)**
#
# \begin{split}
# \sum^n_{i=1} (\hat{y_i}-\bar{y})^2
# \end{split}

# %%
sse = np.sum((y_linear_pred-np.mean(y_test))**2)
sse
# Out:
# 45.91956318529082

# %% [markdown]
# #### **SSR(Residual sum of squares)**
#
# \begin{split}
# \sum^n_{i=1} (y_i-\hat{y_i})^2
# \end{split}

# %%
ssr = np.sum((y_test-y_linear_pred)**2)
ssr
# Out:
# 41.40280912770588

# %% [markdown]
# #### **SST(Total sum of squares)**
#
# \begin{split}
# \sum^n_{i=1} (y_i-\bar{y_i})^2
# \end{split}

# %%
sst = np.sum((y_test-np.mean(y_test))**2)
sst
# Out:
# 101.99999999999999

# %% [markdown]
# #### **결정계수 $R^2$**
# * $R^2$ 범위: 0과 1 사이 존재 (값이 1에 가까울수록 성능이 좋다)
# * $R^2 = 1$: 현재 가지고 있는 x 변수로 y를 100% 설명 가능. 모든 관측치가
# * $R^2=0$: 현재 가지고있는 x변수로 y를 전혀 설명할 수 없다.
#
# \begin{split}
# R^2 = \frac{SSR}{SST} = 1-\frac{SSE}{SST}
# \end{split}

# %%
ssr/sst
# Out:
# 0.40590989340888123

# %%
1-(sse/sst)
# Out:
# 0.5498082040657762

# %%
r2_score(y_test, y_linear_pred)
# Out:
# 0.5940901065911188

# %% [markdown]
# * 함수 정리

# %%
import numpy as np
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

def mean_absolute_percentage_error(y_true, y_pred):
  y_true, y_pred = np.array(y_true), np.array(y_pred)
  return np.mean(np.abs(y_true-y_pred) / y_true) * 100

def norm_mean_absolute_error(y_true, y_pred):
  return mean_absolute_error(y_true, y_pred)/np.mean(np.abs(y_true))

def regression_scores(y_true,y_pred):
  mse = mean_squared_error(y_true, y_pred)
  rmse = np.sqrt(mean_squared_error(y_true, y_pred))
  mae = mean_absolute_error(y_true, y_pred)
  nmae = norm_mean_absolute_error(y_true, y_pred)
  mape = mean_absolute_percentage_error(y_true, y_pred)
  r2 = r2_score(y_true, y_pred)
  return {'mse':np.round(mse,3), 
          'rmse':np.round(rmse,3), 
          'mae':np.round(mae,3), 
          'nmae':np.round(nmae,3), 
          'mape':np.round(mape,3), 
          'r2':np.round(r2,3) }


regression_scores(y_test, y_linear_pred)
# Out:
# {'mae': 0.479,
#  'mape': 24.23,
#  'mse': 0.406,
#  'nmae': 0.689,
#  'r2': 0.594,
#  'rmse': 0.637}

# %% [markdown]
# * 함수 사용하고 데이터프레임으로 나타내기

# %% [markdown]
# ## 다중 회귀 분석
# ---

# %% [markdown]
# ### **| 데이터 전처리**

# %%
import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/rasbt/'
                 'python-machine-learning-book-3rd-edition/'
                 'master/ch10/housing.data.txt',
                 header=None,
                 sep='\s+')

df.columns = ['CRIM', 'ZN', 'INDUS', 'CHAS', 
              'NOX', 'RM', 'AGE', 'DIS', 'RAD', 
              'TAX', 'PTRATIO', 'B', 'LSTAT', 'MEDV']

# %% [markdown]
# * 넘파이 배열로 변환

# %%
df.values #넘파이 배열로 변환
df.head()

X = df.iloc[:,:-1]#나머지
y = df['MEDV'].values #MEDV
X.shape, y.shape
# Out:
# ((506, 13), (506,))

# %% [markdown]
# * 데이터 분할 (테스트 비율 0.2)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2,
                                                    random_state=1)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((404, 13), (102, 13), (404,), (102,))

# %% [markdown]
# * 스케일링 - 정규화 진행

# %%
from sklearn.preprocessing import StandardScaler

sc_x = StandardScaler() #x에 대한 정규화 mean, std가 정해지지 않음
sc_y = StandardScaler() #y에 대한 정규화 mean, std가 정해지지 않음
sc_x.fit(X_train) #인풋 X_train에 대한 mean, std 정해주기
sc_y.fit(y_train.reshape(-1,1)) #아웃풋 y_train에 대한 mean, std 정해주기
#fit 함수의 인풋은 2차 텐서

#sc_x 함수 : 데이터가 들어오면 x - x_train의 평균을 빼주고 / std_xtrain 분산으로 나눠준다.

# %% [markdown]
# * 훈련 데이터 정규화

# %%
X_train = sc_x.fit_transform(X_train)
y_train = sc_y.fit_transform(y_train.reshape(-1,1)).flatten()
X_train.shape, y_train.shape

# %% [markdown]
# * 테스트 데이터 정규화

# %%
X_test = sc_x.fit_transform(X_test)
y_test = sc_y.fit_transform(y_test.reshape(-1,1)).flatten()
X_test.shape, y_test.shape

# %% [markdown]
# ### **| 모델링**
#
# * 여러가지 회귀 모델을 사용하여 회귀 분석 진행

# %% [markdown]
# #### **Linear regression**
#
#
# \begin{split}
# \min_{w} || X w - y||_2^2
# \end{split}

# %%
from sklearn.linear_model import *
linear = LinearRegression()
linear.fit(X_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# #### **Ridge regression**
#
#
# \begin{split}
# \min_{w} || X w - y||_2^2 + \alpha ||w||_2^2
# \end{split}

# %%
ridge = Ridge(alpha=0.1)
ridge.fit(X_train,y_train)
# Out:
# Ridge(alpha=0.1)

# %% [markdown]
# #### **Lasso regression**
#
# \begin{split}
# \min_{w} { \frac{1}{2n_{\text{samples}}} ||X w - y||_2 ^ 2 + \alpha ||w||_1}
# \end{split}

# %%
lasso = Lasso(alpha=0.1)
lasso.fit(X_train,y_train)
# Out:
# Lasso(alpha=0.1)

# %% [markdown]
# #### **Elastic Net**
#
#
# \begin{split}
# \min_{w} { \frac{1}{2n_{\text{samples}}} ||X w - y||_2 ^ 2 + \alpha \rho ||w||_1 +
# \frac{\alpha(1-\rho)}{2} ||w||_2 ^ 2}
# \end{split}

# %%
elastic = ElasticNet(alpha=0.1)
elastic.fit(X_train,y_train)
# Out:
# ElasticNet(alpha=0.1)

# %% [markdown]
# #### **Bayesian Ridge Regression**
#
#
# \begin{split}
# p(w|\lambda) =
# \mathcal{N}(w|0,\lambda^{-1}\mathbf{I}_{p})
# \end{split}

# %%
bayes_ridge = BayesianRidge()
bayes_ridge.fit(X_train,y_train)
# Out:
# BayesianRidge()

# %% [markdown]
# ### **| 성능 비교**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# * `regression_scores` 이용한 회귀 모델 성능 비교

# %%
import numpy as np
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

def mean_absolute_percentage_error(y_true, y_pred):
  y_true, y_pred = np.array(y_true), np.array(y_pred)
  return np.mean(np.abs(y_true-y_pred) / y_true) * 100

def norm_mean_absolute_error(y_true, y_pred):
  return mean_absolute_error(y_true, y_pred)/np.mean(np.abs(y_true))

def regression_scores(y_true,y_pred):
  mse = mean_squared_error(y_true, y_pred)
  rmse = np.sqrt(mean_squared_error(y_true, y_pred))
  mae = mean_absolute_error(y_true, y_pred)
  nmae = norm_mean_absolute_error(y_true, y_pred)
  mape = mean_absolute_percentage_error(y_true, y_pred)
  r2 = r2_score(y_true, y_pred)
  return {'mse':np.round(mse,3), 
          'rmse':np.round(rmse,3), 
          'mae':np.round(mae,3), 
          'nmae':np.round(nmae,3), 
          'mape':np.round(mape,3), 
          'r2':np.round(r2,3) }

# %%
df_score = pd.DataFrame()
for model in ['linear', 'ridge', 'lasso', 'elastic', 'bayes_ridge']:
  y_pred = eval(model).predict(X_test)
  scores = pd.DataFrame(regression_scores(y_test, y_pred), index=[model])
  df_score = pd.concat([df_score, scores])
df_score.style.background_gradient(cmap='Greens_r')
# Out:
# <style type="text/css">
# #T_91f52_row0_col0 {
#   background-color: #005020;
#   color: #f1f1f1;
# }
# #T_91f52_row0_col1 {
#   background-color: #004e1f;
#   color: #f1f1f1;
# }
# #T_91f52_row0_col2 {
#   background-color: #0b7734;
#   color: #f1f1f1;
# }
# #T_91f52_row0_col3, #T_91f52_row1_col0, #T_91f52_row1_col1, #T_91f52_row1_col2, #T_91f52_row1_col3, #T_91f52_row1_col4, #T_91f52_row3_col5 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_91f52_row0_col4 {
#   background-color: #087432;
#   color: #f1f1f1;
# }
# #T_91f52_row0_col5 {
#   background-color: #f0f9ed;
#   color: #000000;
# }
# #T_91f52_row1_col5, #T_91f52_row2_col4, #T_91f52_row3_col0, #T_91f52_row3_col1, #T_91f52_row3_col2, #T_91f52_row3_col3 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_91f52_row2_col0 {
#   background-color: #b8e3b2;
#   color: #000000;
# }
# #T_91f52_row2_col1 {
#   background-color: #bbe4b4;
#   color: #000000;
# }
# #T_91f52_row2_col2 {
#   background-color: #7ac77b;
#   color: #000000;
# }
# #T_91f52_row2_col3, #T_91f52_row4_col3 {
#   background-color: #75c477;
#   color: #000000;
# }
# #T_91f52_row2_col5 {
#   background-color: #2f974e;
#   color: #f1f1f1;
# }
# #T_91f52_row3_col4 {
#   background-color: #e9f7e5;
#   color: #000000;
# }
# #T_91f52_row4_col0, #T_91f52_row4_col1 {
#   background-color: #c8e9c1;
#   color: #000000;
# }
# #T_91f52_row4_col2 {
#   background-color: #8dd08a;
#   color: #000000;
# }
# #T_91f52_row4_col4 {
#   background-color: #94d390;
#   color: #000000;
# }
# #T_91f52_row4_col5 {
#   background-color: #238b45;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_91f52_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >mse</th>
#       <th class="col_heading level0 col1" >rmse</th>
#       <th class="col_heading level0 col2" >mae</th>
#       <th class="col_heading level0 col3" >nmae</th>
#       <th class="col_heading level0 col4" >mape</th>
#       <th class="col_heading level0 col5" >r2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_91f52_level0_row0" class="row_heading level0 row0" >linear</th>
#       <td id="T_91f52_row0_col0" class="data row0 col0" >23.381000</td>
#       <td id="T_91f52_row0_col1" class="data row0 col1" >4.835000</td>
#       <td id="T_91f52_row0_col2" class="data row0 col2" >3.751000</td>
#       <td id="T_91f52_row0_col3" class="data row0 col3" >0.166000</td>
#       <td id="T_91f52_row0_col4" class="data row0 col4" >18.776000</td>
#       <td id="T_91f52_row0_col5" class="data row0 col5" >0.763000</td>
#     </tr>
#     <tr>
#       <th id="T_91f52_level0_row1" class="row_heading level0 row1" >ridge</th>
#       <td id="T_91f52_row1_col0" class="data row1 col0" >23.307000</td>
#       <td id="T_91f52_row1_col1" class="data row1 col1" >4.828000</td>
#       <td id="T_91f52_row1_col2" class="data row1 col2" >3.741000</td>
#       <td id="T_91f52_row1_col3" class="data row1 col3" >0.166000</td>
#       <td id="T_91f52_row1_col4" class="data row1 col4" >18.743000</td>
#       <td id="T_91f52_row1_col5" class="data row1 col5" >0.764000</td>
#     </tr>
#     <tr>
#       <th id="T_91f52_level0_row2" class="row_heading level0 row2" >lasso</th>
#       <td id="T_91f52_row2_col0" class="data row2 col0" >24.716000</td>
#       <td id="T_91f52_row2_col1" class="data row2 col1" >4.972000</td>
#       <td id="T_91f52_row2_col2" class="data row2 col2" >3.772000</td>
#       <td id="T_91f52_row2_col3" class="data row2 col3" >0.167000</td>
#       <td id="T_91f52_row2_col4" class="data row2 col4" >18.959000</td>
#       <td id="T_91f52_row2_col5" class="data row2 col5" >0.750000</td>
#     </tr>
#     <tr>
#       <th id="T_91f52_level0_row3" class="row_heading level0 row3" >elastic</th>
#       <td id="T_91f52_row3_col0" class="data row3 col0" >25.312000</td>
#       <td id="T_91f52_row3_col1" class="data row3 col1" >5.031000</td>
#       <td id="T_91f52_row3_col2" class="data row3 col2" >3.801000</td>
#       <td id="T_91f52_row3_col3" class="data row3 col3" >0.168000</td>
#       <td id="T_91f52_row3_col4" class="data row3 col4" >18.938000</td>
#       <td id="T_91f52_row3_col5" class="data row3 col5" >0.744000</td>
#     </tr>
#     <tr>
#       <th id="T_91f52_level0_row4" class="row_heading level0 row4" >bayes_ridge</th>
#       <td id="T_91f52_row4_col0" class="data row4 col0" >24.814000</td>
#       <td id="T_91f52_row4_col1" class="data row4 col1" >4.981000</td>
#       <td id="T_91f52_row4_col2" class="data row4 col2" >3.775000</td>
#       <td id="T_91f52_row4_col3" class="data row4 col3" >0.167000</td>
#       <td id="T_91f52_row4_col4" class="data row4 col4" >18.870000</td>
#       <td id="T_91f52_row4_col5" class="data row4 col5" >0.749000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# * 실제값과 예측값의 산점도 그리기

# %%
plt.figure(figsize=(5,5))
y_pred = ridge.predict(X_test)
plt.scatter(y_test, y_pred, marker='.')
plt.plot([0,50],[0,50])
plt.xlabel('y_true')
plt.ylabel('y_pred')
# Out:
# Text(0, 0.5, 'y_pred')
