# %%
! git clone https://github.com/linguist7/itedu
# Out:
# Cloning into 'itedu'...
# remote: Enumerating objects: 268, done.
# remote: Counting objects: 100% (268/268), done.
# remote: Compressing objects: 100% (235/235), done.
# remote: Total 268 (delta 69), reused 196 (delta 27), pack-reused 0
# Receiving objects: 100% (268/268), 48.42 MiB | 43.11 MiB/s, done.
# Resolving deltas: 100% (69/69), done.

# %%
import sys
sys.path.append('/content/itedu/SkillTreePython-DeepLearning-main/data')

# %%
from detect_with_yolo import *

# %%
# !wget https://pjreddie.com/media/files/yolov3.weights -O yolov3.weights
# Out:
# --2022-06-22 06:18:00--  https://pjreddie.com/media/files/yolov3.weights
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 248007048 (237M) [application/octet-stream]
# Saving to: ‘yolov3.weights’
#
# yolov3.weights      100%[===================>] 236.52M  38.0MB/s    in 16s
#
# 2022-06-22 06:18:16 (14.8 MB/s) - ‘yolov3.weights’ saved [248007048/248007048]

# %%
weight_file='/content/yolov3.weights'
cfg_file='/content/itedu/SkillTreePython-DeepLearning-main/data/yolov3.cfg'
name_file='/content/itedu/SkillTreePython-DeepLearning-main/data/coco.names'
model, predict_layer_names = set_model(weight_file, cfg_file)
class_names, class_colors = set_label(name_file)

# %%
img_path = 'car4.jpg'#@param ['car.jpg', 'car2.jpg', 'car3.jpg', 'car4.jpg'] 
img_path = f'/content/itedu/SkillTreePython-DeepLearning-main/data/{img_path}'
img = cv2.imread(img_path)
img2detect(img, model, predict_layer_names, class_names, class_colors)
# Out:
# <PIL.Image.Image image mode=RGB size=780x439 at 0x7F10ED1FEA90>
