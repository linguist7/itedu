jpg
#   inflating: 교래자연휴양림/교래자연휴양림_206_41951585.jpg
#   inflating: 교래자연휴양림/교래자연휴양림_207_41951586.jpg
#   inflating: 교래자연휴양림/교래자연휴양림_208_41951588.jpg
#   inflating: 교래자연휴양림/교래자연휴양림_209_41951590.jpg
#   inflating: 교래자연휴양림/교래자연휴양림_210_41951592.jpg
#   inflating: 교래자연휴양림/교래자연휴양림_211_41951594.jpg
#   inflating: 교래자연휴양림/교래자연휴양림_212_41951595.jpg
#   inflating: 교래자연휴양림/교래자연휴양림_213_41951597.jpg
#   inflating: 교래자연휴양림/교래자연휴양림_214_41951599.jpg
#   inflating: 교래자연휴양림/교래자연휴양림_215_41951600.jpg
#   inflating: 교래자연휴양림/교래자연휴양림_216_41951601.jpg
#   inflating: 교래자연휴양림/교래자연휴양림_217_41951602.jpg
#   inflating: 교래자연휴양림/교래자연휴양림_218_41951603.jpg
#   inflating: 교래자연휴양림/교래자연휴양림_219_41951604.jpg
#   inflating: 교래자연휴양림/교래자연휴양림_220_41951606.jpg
#   inflating: 교래자연휴양림/교래자연휴양림_221_41951607.jpg
#   inflating: 교래자연휴양림/교래자연휴양림_222_41951608.jpg
#   inflating: 교래자연휴양림/교래자연휴양림_223_41951610.jpg
#   inflating: 교래자연휴양림/교래자연휴양림_224_41951613.jpg
#   inflating: 교래자연휴양림/교래자연휴양림_225_41951615.jpg
#   inflating: 교래자연휴양림/교래자연휴양림_226_41951616.jpg
#   inflating: 교래자연휴양림/교래자연휴양림_227_41951618.jpg
#   inflating: 교래자연휴양림/교래자연휴양림_228_41951620.jpg
#   inflating: 교래자연휴양림/교래자연휴양림_229_41951621.jpg
#   inflating: 교래자연휴양림/교래자연휴양림_230_41951626.jpg

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
# 제주도에 8개 관광지를 맞추는 모델

# %%
train_gen = ImageDataGenerator(rescale=1.0/255.0, # 0~1로 스케일링
                               validation_split=0.2,
                               width_shift_range = 0.25,
                               height_shift_range = 0.25,
                               rotation_range = 180,
                               shear_range = 0.2,
                               zoom_range = 0.2,
                               horizontal_flip=True,
                               vertical_flip=True,
                               brightness_range = [0.6, 1.4]
                               )
valid_gen = ImageDataGenerator(rescale=1.0/255.0, # 0~1로 스케일링
                               validation_split=0.2
                               )

# %%
IMG_SHAPE = (180, 180)
BATCH_SIZE = 8
SEED = 123
dir_path = '/content/dataset'
# 같은 디렉토리에서 train-valid 나누고 싶다.
train_ds = train_gen.flow_from_directory(dir_path,
                                         target_size=IMG_SHAPE,
                                         batch_size = BATCH_SIZE,
                                         class_mode = 'categorical',
                                         subset='training',
                                         seed = SEED
                                         )
valid_ds = valid_gen.flow_from_directory(dir_path,
                                         target_size=IMG_SHAPE,
                                         batch_size = BATCH_SIZE,
                                         class_mode = 'categorical',
                                         subset='validation',
                                         seed = SEED
                                         )
# Out:
# Found 1065 images belonging to 8 classes.
# Found 263 images belonging to 8 classes.

# %%
import matplotlib.pyplot as plt

# imgs (batchsize, 180,180,3)
# labels 원-핫인코딩이 되어있다! 
plt.figure(figsize=(10,5))
for imgs, labels in train_ds:
  print(imgs.shape, labels.shape)
  for i in range(BATCH_SIZE):
    plt.subplot(2,4,i+1)
    plt.xticks([]);plt.yticks([])
    plt.imshow(imgs[i])
  break
# Out:
# (8, 180, 180, 3) (8, 8)

# %% [markdown]
# ## 모델 학습

# %%
IMG_SHAPE+(3,)
# Out:
# (180, 180, 3)

# %%
base_model = tf.keras.applications.EfficientNetB7(weights='imagenet',
                                                  include_top=False,
                                                  input_shape=IMG_SHAPE+(3,)
                                                  )
base_model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb7_notop.h5
# 258080768/258076736 [==============================] - 2s 0us/step
# 258088960/258076736 [==============================] - 2s 0us/step
# Model: "efficientnetb7"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 180, 180, 3  0           []
#                                 )]
#
#  rescaling (Rescaling)          (None, 180, 180, 3)  0           ['input_1[0][0]']
#
#  normalization (Normalization)  (None, 180, 180, 3)  7           ['rescaling[0][0]']
#
#  stem_conv_pad (ZeroPadding2D)  (None, 181, 181, 3)  0           ['normalization[0][0]']
#
#  stem_conv (Conv2D)             (None, 90, 90, 64)   1728        ['stem_conv_pad[0][0]']
#
#  stem_bn (BatchNormalization)   (None, 90, 90, 64)   256         ['stem_conv[0][0]']
#
#  stem_activation (Activation)   (None, 90, 90, 64)   0           ['stem_bn[0][0]']
#
#  block1a_dwconv (DepthwiseConv2  (None, 90, 90, 64)  576         ['stem_activation[0][0]']
#  D)
#
#  block1a_bn (BatchNormalization  (None, 90, 90, 64)  256         ['block1a_dwconv[0][0]']
#  )
#
#  block1a_activation (Activation  (None, 90, 90, 64)  0           ['block1a_bn[0][0]']
#  )
#
#  block1a_se_squeeze (GlobalAver  (None, 64)          0           ['block1a_activation[0][0]']
#  agePooling2D)
#
#  block1a_se_reshape (Reshape)   (None, 1, 1, 64)     0           ['block1a_se_squeeze[0][0]']
#
#  block1a_se_reduce (Conv2D)     (None, 1, 1, 16)     1040        ['block1a_se_reshape[0][0]']
#
#  block1a_se_expand (Conv2D)     (None, 1, 1, 64)     1088        ['block1a_se_reduce[0][0]']
#
#  block1a_se_excite (Multiply)   (None, 90, 90, 64)   0           ['block1a_activation[0][0]',
#                                                                   'block1a_se_expand[0][0]']
#
#  block1a_project_conv (Conv2D)  (None, 90, 90, 32)   2048        ['block1a_se_excite[0][0]']
#
#  block1a_project_bn (BatchNorma  (None, 90, 90, 32)  128         ['block1a_project_conv[0][0]']
#  lization)
#
#  block1b_dwconv (DepthwiseConv2  (None, 90, 90, 32)  288         ['block1a_project_bn[0][0]']
#  D)
#
#  block1b_bn (BatchNormalization  (None, 90, 90, 32)  128         ['block1b_dwconv[0][0]']
#  )
#
#  block1b_activation (Activation  (None, 90, 90, 32)  0           ['block1b_bn[0][0]']
#  )
#
#  block1b_se_squeeze (GlobalAver  (None, 32)          0           ['block1b_activation[0][0]']
#  agePooling2D)
#
#  block1b_se_reshape (Reshape)   (None, 1, 1, 32)     0           ['block1b_se_squeeze[0][0]']
#
#  block1b_se_reduce (Conv2D)     (None, 1, 1, 8)      264         ['block1b_se_reshape[0][0]']
#
#  block1b_se_expand (Conv2D)     (None, 1, 1, 32)     288         ['block1b_se_reduce[0][0]']
#
#  block1b_se_excite (Multiply)   (None, 90, 90, 32)   0           ['block1b_activation[0][0]',
#                                                                   'block1b_se_expand[0][0]']
#
#  block1b_project_conv (Conv2D)  (None, 90, 90, 32)   1024        ['block1b_se_excite[0][0]']
#
#  block1b_project_bn (BatchNorma  (None, 90, 90, 32)  128         ['block1b_project_conv[0][0]']
#  lization)
#
#  block1b_drop (Dropout)         (None, 90, 90, 32)   0           ['block1b_project_bn[0][0]']
#
#  block1b_add (Add)              (None, 90, 90, 32)   0           ['block1b_drop[0][0]',
#                                                                   'block1a_project_bn[0][0]']
#
#  block1c_dwconv (DepthwiseConv2  (None, 90, 90, 32)  288         ['block1b_add[0][0]']
#  D)
#
#  block1c_bn (BatchNormalization  (None, 90, 90, 32)  128         ['block1c_dwconv[0][0]']
#  )
#
#  block1c_activation (Activation  (None, 90, 90, 32)  0           ['block1c_bn[0][0]']
#  )
#
#  block1c_se_squeeze (GlobalAver  (None, 32)          0           ['block1c_activation[0][0]']
#  agePooling2D)
#
#  block1c_se_reshape (Reshape)   (None, 1, 1, 32)     0           ['block1c_se_squeeze[0][0]']
#
#  block1c_se_reduce (Conv2D)     (None, 1, 1, 8)      264         ['block1c_se_reshape[0][0]']
#
#  block1c_se_expand (Conv2D)     (None, 1, 1, 32)     288         ['block1c_se_reduce[0][0]']
#
#  block1c_se_excite (Multiply)   (None, 90, 90, 32)   0           ['block1c_activation[0][0]',
#                                                                   'block1c_se_expand[0][0]']
#
#  block1c_project_conv (Conv2D)  (None, 90, 90, 32)   1024        ['block1c_se_excite[0][0]']
#
#  block1c_project_bn (BatchNorma  (None, 90, 90, 32)  128         ['block1c_project_conv[0][0]']
#  lization)
#
#  block1c_drop (Dropout)         (None, 90, 90, 32)   0           ['block1c_project_bn[0][0]']
#
#  block1c_add (Add)              (None, 90, 90, 32)   0           ['block1c_drop[0][0]',
#                                                                   'block1b_add[0][0]']
#
#  block1d_dwconv (DepthwiseConv2  (None, 90, 90, 32)  288         ['block1c_add[0][0]']
#  D)
#
#  block1d_bn (BatchNormalization  (None, 90, 90, 32)  128         ['block1d_dwconv[0][0]']
#  )
#
#  block1d_activation (Activation  (None, 90, 90, 32)  0           ['block1d_bn[0][0]']
#  )
#
#  block1d_se_squeeze (GlobalAver  (None, 32)          0           ['block1d_activation[0][0]']
#  agePooling2D)
#
#  block1d_se_reshape (Reshape)   (None, 1, 1, 32)     0           ['block1d_se_squeeze[0][0]']
#
#  block1d_se_reduce (Conv2D)     (None, 1, 1, 8)      264         ['block1d_se_reshape[0][0]']
#
#  block1d_se_expand (Conv2D)     (None, 1, 1, 32)     288         ['block1d_se_reduce[0][0]']
#
#  block1d_se_excite (Multiply)   (None, 90, 90, 32)   0           ['block1d_activation[0][0]',
#                                                                   'block1d_se_expand[0][0]']
#
#  block1d_project_conv (Conv2D)  (None, 90, 90, 32)   1024        ['block1d_se_excite[0][0]']
#
#  block1d_project_bn (BatchNorma  (None, 90, 90, 32)  128         ['block1d_project_conv[0][0]']
#  lization)
#
#  block1d_drop (Dropout)         (None, 90, 90, 32)   0           ['block1d_project_bn[0][0]']
#
#  block1d_add (Add)              (None, 90, 90, 32)   0           ['block1d_drop[0][0]',
#                                                                   'block1c_add[0][0]']
#
#  block2a_expand_conv (Conv2D)   (None, 90, 90, 192)  6144        ['block1d_add[0][0]']
#
#  block2a_expand_bn (BatchNormal  (None, 90, 90, 192)  768        ['block2a_expand_conv[0][0]']
#  ization)
#
#  block2a_expand_activation (Act  (None, 90, 90, 192)  0          ['block2a_expand_bn[0][0]']
#  ivation)
#
#  block2a_dwconv_pad (ZeroPaddin  (None, 91, 91, 192)  0          ['block2a_expand_activation[0][0]
#  g2D)                                                            ']
#
#  block2a_dwconv (DepthwiseConv2  (None, 45, 45, 192)  1728       ['block2a_dwconv_pad[0][0]']
#  D)
#
#  block2a_bn (BatchNormalization  (None, 45, 45, 192)  768        ['block2a_dwconv[0][0]']
#  )
#
#  block2a_activation (Activation  (None, 45, 45, 192)  0          ['block2a_bn[0][0]']
#  )
#
#  block2a_se_squeeze (GlobalAver  (None, 192)         0           ['block2a_activation[0][0]']
#  agePooling2D)
#
#  block2a_se_reshape (Reshape)   (None, 1, 1, 192)    0           ['block2a_se_squeeze[0][0]']
#
#  block2a_se_reduce (Conv2D)     (None, 1, 1, 8)      1544        ['block2a_se_reshape[0][0]']
#
#  block2a_se_expand (Conv2D)     (None, 1, 1, 192)    1728        ['block2a_se_reduce[0][0]']
#
#  block2a_se_excite (Multiply)   (None, 45, 45, 192)  0           ['block2a_activation[0][0]',
#                                                                   'block2a_se_expand[0][0]']
#
#  block2a_project_conv (Conv2D)  (None, 45, 45, 48)   9216        ['block2a_se_excite[0][0]']
#
#  block2a_project_bn (BatchNorma  (None, 45, 45, 48)  192         ['block2a_project_conv[0][0]']
#  lization)
#
#  block2b_expand_conv (Conv2D)   (None, 45, 45, 288)  13824       ['block2a_project_bn[0][0]']
#
#  block2b_expand_bn (BatchNormal  (None, 45, 45, 288)  1152       ['block2b_expand_conv[0][0]']
#  ization)
#
#  block2b_expand_activation (Act  (None, 45, 45, 288)  0          ['block2b_expand_bn[0][0]']
#  ivation)
#
#  block2b_dwconv (DepthwiseConv2  (None, 45, 45, 288)  2592       ['block2b_expand_activation[0][0]
#  D)                                                              ']
#
#  block2b_bn (BatchNormalization  (None, 45, 45, 288)  1152       ['block2b_dwconv[0][0]']
#  )
#
#  block2b_activation (Activation  (None, 45, 45, 288)  0          ['block2b_bn[0][0]']
#  )
#
#  block2b_se_squeeze (GlobalAver  (None, 288)         0           ['block2b_activation[0][0]']
#  agePooling2D)
#
#  block2b_se_reshape (Reshape)   (None, 1, 1, 288)    0           ['block2b_se_squeeze[0][0]']
#
#  block2b_se_reduce (Conv2D)     (None, 1, 1, 12)     3468        ['block2b_se_reshape[0][0]']
#
#  block2b_se_expand (Conv2D)     (None, 1, 1, 288)    3744        ['block2b_se_reduce[0][0]']
#
#  block2b_se_excite (Multiply)   (None, 45, 45, 288)  0           ['block2b_activation[0][0]',
#                                                                   'block2b_se_expand[0][0]']
#
#  block2b_project_conv (Conv2D)  (None, 45, 45, 48)   13824       ['block2b_se_excite[0][0]']
#
#  block2b_project_bn (BatchNorma  (None, 45, 45, 48)  192         ['block2b_project_conv[0][0]']
#  lization)
#
#  block2b_drop (Dropout)         (None, 45, 45, 48)   0           ['block2b_project_bn[0][0]']
#
#  block2b_add (Add)              (None, 45, 45, 48)   0           ['block2b_drop[0][0]',
#                                                                   'block2a_project_bn[0][0]']
#
#  block2c_expand_conv (Conv2D)   (None, 45, 45, 288)  13824       ['block2b_add[0][0]']
#
#  block2c_expand_bn (BatchNormal  (None, 45, 45, 288)  1152       ['block2c_expand_conv[0][0]']
#  ization)
#
#  block2c_expand_activation (Act  (None, 45, 45, 288)  0          ['block2c_expand_bn[0][0]']
#  ivation)
#
#  block2c_dwconv (DepthwiseConv2  (None, 45, 45, 288)  2592       ['block2c_expand_activation[0][0]
#  D)                                                              ']
#
#  block2c_bn (BatchNormalization  (None, 45, 45, 288)  1152       ['block2c_dwconv[0][0]']
#  )
#
#  block2c_activation (Activation  (None, 45, 45, 288)  0          ['block2c_bn[0][0]']
#  )
#
#  block2c_se_squeeze (GlobalAver  (None, 288)         0           ['block2c_activation[0][0]']
#  agePooling2D)
#
#  block2c_se_reshape (Reshape)   (None, 1, 1, 288)    0           ['block2c_se_squeeze[0][0]']
#
#  block2c_se_reduce (Conv2D)     (None, 1, 1, 12)     3468        ['block2c_se_reshape[0][0]']
#
#  block2c_se_expand (Conv2D)     (None, 1, 1, 288)    3744        ['block2c_se_reduce[0][0]']
#
#  block2c_se_excite (Multiply)   (None, 45, 45, 288)  0           ['block2c_activation[0][0]',
#                                                                   'block2c_se_expand[0][0]']
#
#  block2c_project_conv (Conv2D)  (None, 45, 45, 48)   13824       ['block2c_se_excite[0][0]']
#
#  block2c_project_bn (BatchNorma  (None, 45, 45, 48)  192         ['block2c_project_conv[0][0]']
#  lization)
#
#  block2c_drop (Dropout)         (None, 45, 45, 48)   0           ['block2c_project_bn[0][0]']
#
#  block2c_add (Add)              (None, 45, 45, 48)   0           ['block2c_drop[0][0]',
#                                                                   'block2b_add[0][0]']
#
#  block2d_expand_conv (Conv2D)   (None, 45, 45, 288)  13824       ['block2c_add[0][0]']
#
#  block2d_expand_bn (BatchNormal  (None, 45, 45, 288)  1152       ['block2d_expand_conv[0][0]']
#  ization)
#
#  block2d_expand_activation (Act  (None, 45, 45, 288)  0          ['block2d_expand_bn[0][0]']
#  ivation)
#
#  block2d_dwconv (DepthwiseConv2  (None, 45, 45, 288)  2592       ['block2d_expand_activation[0][0]
#  D)                                                              ']
#
#  block2d_bn (BatchNormalization  (None, 45, 45, 288)  1152       ['block2d_dwconv[0][0]']
#  )
#
#  block2d_activation (Activation  (None, 45, 45, 288)  0          ['block2d_bn[0][0]']
#  )
#
#  block2d_se_squeeze (GlobalAver  (None, 288)         0           ['block2d_activation[0][0]']
#  agePooling2D)
#
#  block2d_se_reshape (Reshape)   (None, 1, 1, 288)    0           ['block2d_se_squeeze[0][0]']
#
#  block2d_se_reduce (Conv2D)     (None, 1, 1, 12)     3468        ['block2d_se_reshape[0][0]']
#
#  block2d_se_expand (Conv2D)     (None, 1, 1, 288)    3744        ['block2d_se_reduce[0][0]']
#
#  block2d_se_excite (Multiply)   (None, 45, 45, 288)  0           ['block2d_activation[0][0]',
#                                                                   'block2d_se_expand[0][0]']
#
#  block2d_project_conv (Conv2D)  (None, 45, 45, 48)   13824       ['block2d_se_excite[0][0]']
#
#  block2d_project_bn (BatchNorma  (None, 45, 45, 48)  192         ['block2d_project_conv[0][0]']
#  lization)
#
#  block2d_drop (Dropout)         (None, 45, 45, 48)   0           ['block2d_project_bn[0][0]']
#
#  block2d_add (Add)              (None, 45, 45, 48)   0           ['block2d_drop[0][0]',
#                                                                   'block2c_add[0][0]']
#
#  block2e_expand_conv (Conv2D)   (None, 45, 45, 288)  13824       ['block2d_add[0][0]']
#
#  block2e_expand_bn (BatchNormal  (None, 45, 45, 288)  1152       ['block2e_expand_conv[0][0]']
#  ization)
#
#  block2e_expand_activation (Act  (None, 45, 45, 288)  0          ['block2e_expand_bn[0][0]']
#  ivation)
#
#  block2e_dwconv (DepthwiseConv2  (None, 45, 45, 288)  2592       ['block2e_expand_activation[0][0]
#  D)                                                              ']
#
#  block2e_bn (BatchNormalization  (None, 45, 45, 288)  1152       ['block2e_dwconv[0][0]']
#  )
#
#  block2e_activation (Activation  (None, 45, 45, 288)  0          ['block2e_bn[0][0]']
#  )
#
#  block2e_se_squeeze (GlobalAver  (None, 288)         0           ['block2e_activation[0][0]']
#  agePooling2D)
#
#  block2e_se_reshape (Reshape)   (None, 1, 1, 288)    0           ['block2e_se_squeeze[0][0]']
#
#  block2e_se_reduce (Conv2D)     (None, 1, 1, 12)     3468        ['block2e_se_reshape[0][0]']
#
#  block2e_se_expand (Conv2D)     (None, 1, 1, 288)    3744        ['block2e_se_reduce[0][0]']
#
#  block2e_se_excite (Multiply)   (None, 45, 45, 288)  0           ['block2e_activation[0][0]',
#                                                                   'block2e_se_expand[0][0]']
#
#  block2e_project_conv (Conv2D)  (None, 45, 45, 48)   13824       ['block2e_se_excite[0][0]']
#
#  block2e_project_bn (BatchNorma  (None, 45, 45, 48)  192         ['block2e_project_conv[0][0]']
#  lization)
#
#  block2e_drop (Dropout)         (None, 45, 45, 48)   0           ['block2e_project_bn[0][0]']
#
#  block2e_add (Add)              (None, 45, 45, 48)   0           ['block2e_drop[0][0]',
#                                                                   'block2d_add[0][0]']
#
#  block2f_expand_conv (Conv2D)   (None, 45, 45, 288)  13824       ['block2e_add[0][0]']
#
#  block2f_expand_bn (BatchNormal  (None, 45, 45, 288)  1152       ['block2f_expand_conv[0][0]']
#  ization)
#
#  block2f_expand_activation (Act  (None, 45, 45, 288)  0          ['block2f_expand_bn[0][0]']
#  ivation)
#
#  block2f_dwconv (DepthwiseConv2  (None, 45, 45, 288)  2592       ['block2f_expand_activation[0][0]
#  D)                                                              ']
#
#  block2f_bn (BatchNormalization  (None, 45, 45, 288)  1152       ['block2f_dwconv[0][0]']
#  )
#
#  block2f_activation (Activation  (None, 45, 45, 288)  0          ['block2f_bn[0][0]']
#  )
#
#  block2f_se_squeeze (GlobalAver  (None, 288)         0           ['block2f_activation[0][0]']
#  agePooling2D)
#
#  block2f_se_reshape (Reshape)   (None, 1, 1, 288)    0           ['block2f_se_squeeze[0][0]']
#
#  block2f_se_reduce (Conv2D)     (None, 1, 1, 12)     3468        ['block2f_se_reshape[0][0]']
#
#  block2f_se_expand (Conv2D)     (None, 1, 1, 288)    3744        ['block2f_se_reduce[0][0]']
#
#  block2f_se_excite (Multiply)   (None, 45, 45, 288)  0           ['block2f_activation[0][0]',
#                                                                   'block2f_se_expand[0][0]']
#
#  block2f_project_conv (Conv2D)  (None, 45, 45, 48)   13824       ['block2f_se_excite[0][0]']
#
#  block2f_project_bn (BatchNorma  (None, 45, 45, 48)  192         ['block2f_project_conv[0][0]']
#  lization)
#
#  block2f_drop (Dropout)         (None, 45, 45, 48)   0           ['block2f_project_bn[0][0]']
#
#  block2f_add (Add)              (None, 45, 45, 48)   0           ['block2f_drop[0][0]',
#                                                                   'block2e_add[0][0]']
#
#  block2g_expand_conv (Conv2D)   (None, 45, 45, 288)  13824       ['block2f_add[0][0]']
#
#  block2g_expand_bn (BatchNormal  (None, 45, 45, 288)  1152       ['block2g_expand_conv[0][0]']
#  ization)
#
#  block2g_expand_activation (Act  (None, 45, 45, 288)  0          ['block2g_expand_bn[0][0]']
#  ivation)
#
#  block2g_dwconv (DepthwiseConv2  (None, 45, 45, 288)  2592       ['block2g_expand_activation[0][0]
#  D)                                                              ']
#
#  block2g_bn (BatchNormalization  (None, 45, 45, 288)  1152       ['block2g_dwconv[0][0]']
#  )
#
#  block2g_activation (Activation  (None, 45, 45, 288)  0          ['block2g_bn[0][0]']
#  )
#
#  block2g_se_squeeze (GlobalAver  (None, 288)         0           ['block2g_activation[0][0]']
#  agePooling2D)
#
#  block2g_se_reshape (Reshape)   (None, 1, 1, 288)    0           ['block2g_se_squeeze[0][0]']
#
#  block2g_se_reduce (Conv2D)     (None, 1, 1, 12)     3468        ['block2g_se_reshape[0][0]']
#
#  block2g_se_expand (Conv2D)     (None, 1, 1, 288)    3744        ['block2g_se_reduce[0][0]']
#
#  block2g_se_excite (Multiply)   (None, 45, 45, 288)  0           ['block2g_activation[0][0]',
#                                                                   'block2g_se_expand[0][0]']
#
#  block2g_project_conv (Conv2D)  (None, 45, 45, 48)   13824       ['block2g_se_excite[0][0]']
#
#  block2g_project_bn (BatchNorma  (None, 45, 45, 48)  192         ['block2g_project_conv[0][0]']
#  lization)
#
#  block2g_drop (Dropout)         (None, 45, 45, 48)   0           ['block2g_project_bn[0][0]']
#
#  block2g_add (Add)              (None, 45, 45, 48)   0           ['block2g_drop[0][0]',
#                                                                   'block2f_add[0][0]']
#
#  block3a_expand_conv (Conv2D)   (None, 45, 45, 288)  13824       ['block2g_add[0][0]']
#
#  block3a_expand_bn (BatchNormal  (None, 45, 45, 288)  1152       ['block3a_expand_conv[0][0]']
#  ization)
#
#  block3a_expand_activation (Act  (None, 45, 45, 288)  0          ['block3a_expand_bn[0][0]']
#  ivation)
#
#  block3a_dwconv_pad (ZeroPaddin  (None, 49, 49, 288)  0          ['block3a_expand_activation[0][0]
#  g2D)                                                            ']
#
#  block3a_dwconv (DepthwiseConv2  (None, 23, 23, 288)  7200       ['block3a_dwconv_pad[0][0]']
#  D)
#
#  block3a_bn (BatchNormalization  (None, 23, 23, 288)  1152       ['block3a_dwconv[0][0]']
#  )
#
#  block3a_activation (Activation  (None, 23, 23, 288)  0          ['block3a_bn[0][0]']
#  )
#
#  block3a_se_squeeze (GlobalAver  (None, 288)         0           ['block3a_activation[0][0]']
#  agePooling2D)
#
#  block3a_se_reshape (Reshape)   (None, 1, 1, 288)    0           ['block3a_se_squeeze[0][0]']
#
#  block3a_se_reduce (Conv2D)     (None, 1, 1, 12)     3468        ['block3a_se_reshape[0][0]']
#
#  block3a_se_expand (Conv2D)     (None, 1, 1, 288)    3744        ['block3a_se_reduce[0][0]']
#
#  block3a_se_excite (Multiply)   (None, 23, 23, 288)  0           ['block3a_activation[0][0]',
#                                                                   'block3a_se_expand[0][0]']
#
#  block3a_project_conv (Conv2D)  (None, 23, 23, 80)   23040       ['block3a_se_excite[0][0]']
#
#  block3a_project_bn (BatchNorma  (None, 23, 23, 80)  320         ['block3a_project_conv[0][0]']
#  lization)
#
#  block3b_expand_conv (Conv2D)   (None, 23, 23, 480)  38400       ['block3a_project_bn[0][0]']
#
#  block3b_expand_bn (BatchNormal  (None, 23, 23, 480)  1920       ['block3b_expand_conv[0][0]']
#  ization)
#
#  block3b_expand_activation (Act  (None, 23, 23, 480)  0          ['block3b_expand_bn[0][0]']
#  ivation)
#
#  block3b_dwconv (DepthwiseConv2  (None, 23, 23, 480)  12000      ['block3b_expand_activation[0][0]
#  D)                                                              ']
#
#  block3b_bn (BatchNormalization  (None, 23, 23, 480)  1920       ['block3b_dwconv[0][0]']
#  )
#
#  block3b_activation (Activation  (None, 23, 23, 480)  0          ['block3b_bn[0][0]']
#  )
#
#  block3b_se_squeeze (GlobalAver  (None, 480)         0           ['block3b_activation[0][0]']
#  agePooling2D)
#
#  block3b_se_reshape (Reshape)   (None, 1, 1, 480)    0           ['block3b_se_squeeze[0][0]']
#
#  block3b_se_reduce (Conv2D)     (None, 1, 1, 20)     9620        ['block3b_se_reshape[0][0]']
#
#  block3b_se_expand (Conv2D)     (None, 1, 1, 480)    10080       ['block3b_se_reduce[0][0]']
#
#  block3b_se_excite (Multiply)   (None, 23, 23, 480)  0           ['block3b_activation[0][0]',
#                                                                   'block3b_se_expand[0][0]']
#
#  block3b_project_conv (Conv2D)  (None, 23, 23, 80)   38400       ['block3b_se_excite[0][0]']
#
#  block3b_project_bn (BatchNorma  (None, 23, 23, 80)  320         ['block3b_project_conv[0][0]']
#  lization)
#
#  block3b_drop (Dropout)         (None, 23, 23, 80)   0           ['block3b_project_bn[0][0]']
#
#  block3b_add (Add)              (None, 23, 23, 80)   0           ['block3b_drop[0][0]',
# ...
#
#  block7a_expand_conv (Conv2D)   (None, 6, 6, 2304)   884736      ['block6m_add[0][0]']
#
#  block7a_expand_bn (BatchNormal  (None, 6, 6, 2304)  9216        ['block7a_expand_conv[0][0]']
#  ization)
#
#  block7a_expand_activation (Act  (None, 6, 6, 2304)  0           ['block7a_expand_bn[0][0]']
#  ivation)
#
#  block7a_dwconv (DepthwiseConv2  (None, 6, 6, 2304)  20736       ['block7a_expand_activation[0][0]
#  D)                                                              ']
#
#  block7a_bn (BatchNormalization  (None, 6, 6, 2304)  9216        ['block7a_dwconv[0][0]']
#  )
#
#  block7a_activation (Activation  (None, 6, 6, 2304)  0           ['block7a_bn[0][0]']
#  )
#
#  block7a_se_squeeze (GlobalAver  (None, 2304)        0           ['block7a_activation[0][0]']
#  agePooling2D)
#
#  block7a_se_reshape (Reshape)   (None, 1, 1, 2304)   0           ['block7a_se_squeeze[0][0]']
#
#  block7a_se_reduce (Conv2D)     (None, 1, 1, 96)     221280      ['block7a_se_reshape[0][0]']
#
#  block7a_se_expand (Conv2D)     (None, 1, 1, 2304)   223488      ['block7a_se_reduce[0][0]']
#
#  block7a_se_excite (Multiply)   (None, 6, 6, 2304)   0           ['block7a_activation[0][0]',
#                                                                   'block7a_se_expand[0][0]']
#
#  block7a_project_conv (Conv2D)  (None, 6, 6, 640)    1474560     ['block7a_se_excite[0][0]']
#
#  block7a_project_bn (BatchNorma  (None, 6, 6, 640)   2560        ['block7a_project_conv[0][0]']
#  lization)
#
#  block7b_expand_conv (Conv2D)   (None, 6, 6, 3840)   2457600     ['block7a_project_bn[0][0]']
#
#  block7b_expand_bn (BatchNormal  (None, 6, 6, 3840)  15360       ['block7b_expand_conv[0][0]']
#  ization)
#
#  block7b_expand_activation (Act  (None, 6, 6, 3840)  0           ['block7b_expand_bn[0][0]']
#  ivation)
#
#  block7b_dwconv (DepthwiseConv2  (None, 6, 6, 3840)  34560       ['block7b_expand_activation[0][0]
#  D)                                                              ']
#
#  block7b_bn (BatchNormalization  (None, 6, 6, 3840)  15360       ['block7b_dwconv[0][0]']
#  )
#
#  block7b_activation (Activation  (None, 6, 6, 3840)  0           ['block7b_bn[0][0]']
#  )
#
#  block7b_se_squeeze (GlobalAver  (None, 3840)        0           ['block7b_activation[0][0]']
#  agePooling2D)
#
#  block7b_se_reshape (Reshape)   (None, 1, 1, 3840)   0           ['block7b_se_squeeze[0][0]']
#
#  block7b_se_reduce (Conv2D)     (None, 1, 1, 160)    614560      ['block7b_se_reshape[0][0]']
#
#  block7b_se_expand (Conv2D)     (None, 1, 1, 3840)   618240      ['block7b_se_reduce[0][0]']
#
#  block7b_se_excite (Multiply)   (None, 6, 6, 3840)   0           ['block7b_activation[0][0]',
#                                                                   'block7b_se_expand[0][0]']
#
#  block7b_project_conv (Conv2D)  (None, 6, 6, 640)    2457600     ['block7b_se_excite[0][0]']
#
#  block7b_project_bn (BatchNorma  (None, 6, 6, 640)   2560        ['block7b_project_conv[0][0]']
#  lization)
#
#  block7b_drop (Dropout)         (None, 6, 6, 640)    0           ['block7b_project_bn[0][0]']
#
#  block7b_add (Add)              (None, 6, 6, 640)    0           ['block7b_drop[0][0]',
#                                                                   'block7a_project_bn[0][0]']
#
#  block7c_expand_conv (Conv2D)   (None, 6, 6, 3840)   2457600     ['block7b_add[0][0]']
#
#  block7c_expand_bn (BatchNormal  (None, 6, 6, 3840)  15360       ['block7c_expand_conv[0][0]']
#  ization)
#
#  block7c_expand_activation (Act  (None, 6, 6, 3840)  0           ['block7c_expand_bn[0][0]']
#  ivation)
#
#  block7c_dwconv (DepthwiseConv2  (None, 6, 6, 3840)  34560       ['block7c_expand_activation[0][0]
#  D)                                                              ']
#
#  block7c_bn (BatchNormalization  (None, 6, 6, 3840)  15360       ['block7c_dwconv[0][0]']
#  )
#
#  block7c_activation (Activation  (None, 6, 6, 3840)  0           ['block7c_bn[0][0]']
#  )
#
#  block7c_se_squeeze (GlobalAver  (None, 3840)        0           ['block7c_activation[0][0]']
#  agePooling2D)
#
#  block7c_se_reshape (Reshape)   (None, 1, 1, 3840)   0           ['block7c_se_squeeze[0][0]']
#
#  block7c_se_reduce (Conv2D)     (None, 1, 1, 160)    614560      ['block7c_se_reshape[0][0]']
#
#  block7c_se_expand (Conv2D)     (None, 1, 1, 3840)   618240      ['block7c_se_reduce[0][0]']
#
#  block7c_se_excite (Multiply)   (None, 6, 6, 3840)   0           ['block7c_activation[0][0]',
#                                                                   'block7c_se_expand[0][0]']
#
#  block7c_project_conv (Conv2D)  (None, 6, 6, 640)    2457600     ['block7c_se_excite[0][0]']
#
#  block7c_project_bn (BatchNorma  (None, 6, 6, 640)   2560        ['block7c_project_conv[0][0]']
#  lization)
#
#  block7c_drop (Dropout)         (None, 6, 6, 640)    0           ['block7c_project_bn[0][0]']
#
#  block7c_add (Add)              (None, 6, 6, 640)    0           ['block7c_drop[0][0]',
#                                                                   'block7b_add[0][0]']
#
#  block7d_expand_conv (Conv2D)   (None, 6, 6, 3840)   2457600     ['block7c_add[0][0]']
#
#  block7d_expand_bn (BatchNormal  (None, 6, 6, 3840)  15360       ['block7d_expand_conv[0][0]']
#  ization)
#
#  block7d_expand_activation (Act  (None, 6, 6, 3840)  0           ['block7d_expand_bn[0][0]']
#  ivation)
#
#  block7d_dwconv (DepthwiseConv2  (None, 6, 6, 3840)  34560       ['block7d_expand_activation[0][0]
#  D)                                                              ']
#
#  block7d_bn (BatchNormalization  (None, 6, 6, 3840)  15360       ['block7d_dwconv[0][0]']
#  )
#
#  block7d_activation (Activation  (None, 6, 6, 3840)  0           ['block7d_bn[0][0]']
#  )
#
#  block7d_se_squeeze (GlobalAver  (None, 3840)        0           ['block7d_activation[0][0]']
#  agePooling2D)
#
#  block7d_se_reshape (Reshape)   (None, 1, 1, 3840)   0           ['block7d_se_squeeze[0][0]']
#
#  block7d_se_reduce (Conv2D)     (None, 1, 1, 160)    614560      ['block7d_se_reshape[0][0]']
#
#  block7d_se_expand (Conv2D)     (None, 1, 1, 3840)   618240      ['block7d_se_reduce[0][0]']
#
#  block7d_se_excite (Multiply)   (None, 6, 6, 3840)   0           ['block7d_activation[0][0]',
#                                                                   'block7d_se_expand[0][0]']
#
#  block7d_project_conv (Conv2D)  (None, 6, 6, 640)    2457600     ['block7d_se_excite[0][0]']
#
#  block7d_project_bn (BatchNorma  (None, 6, 6, 640)   2560        ['block7d_project_conv[0][0]']
#  lization)
#
#  block7d_drop (Dropout)         (None, 6, 6, 640)    0           ['block7d_project_bn[0][0]']
#
#  block7d_add (Add)              (None, 6, 6, 640)    0           ['block7d_drop[0][0]',
#                                                                   'block7c_add[0][0]']
#
#  top_conv (Conv2D)              (None, 6, 6, 2560)   1638400     ['block7d_add[0][0]']
#
#  top_bn (BatchNormalization)    (None, 6, 6, 2560)   10240       ['top_conv[0][0]']
#
#  top_activation (Activation)    (None, 6, 6, 2560)   0           ['top_bn[0][0]']
#
# ==================================================================================================
# Total params: 64,097,687
# Trainable params: 63,786,960
# Non-trainable params: 310,727
# __________________________________________________________________________________________________

# %%
from tensorflow.keras import layers, models, utils, optimizers

# %%
# GlobalAveragePooling  (None, 2560)
# Dropout
# Dense
def create_model(base_model):
  x = layers.Input(shape=IMG_SHAPE+(3,))
  y = base_model(x)
  y = layers.GlobalAvgPool2D()(y)
  y = layers.Dropout(0.5)(y)
  y = layers.Dense(8, activation='softmax')(y)
  return models.Model(x,y)

model = create_model(base_model)
base_model.trainable = True
model.compile(loss = 'categorical_crossentropy',
              optimizer = optimizers.RMSprop(learning_rate=0.0002 ), # 학습률을 작게
              metrics=['acc']) 
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 180, 180, 3)]     0
#
#  efficientnetb7 (Functional)  (None, 6, 6, 2560)       64097687
#
#  global_average_pooling2d (G  (None, 2560)             0
#  lobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 2560)              0
#
#  dense (Dense)               (None, 8)                 20488
#
# =================================================================
# Total params: 64,118,175
# Trainable params: 63,807,448
# Non-trainable params: 310,727
# _________________________________________________________________

# %%
from tensorflow.keras import callbacks

save_path = '/content/drive/MyDrive/eff_landmark'
tb = callbacks.TensorBoard(log_dir = f'{save_path}/tb_log')
ckp = callbacks.ModelCheckpoint(filepath=f'{save_path}/model.h5',
                                save_best_only=True,
                                monitor='val_acc'
                                )
TRAIN_STEP = train_ds.n // BATCH_SIZE
VALID_STEP = valid_ds.n // BATCH_SIZE
history = model.fit(train_ds, 
                    validation_data=valid_ds,
                    epochs=20,
                    shuffle=True,
                    callbacks=[tb, ckp],
                    # 계산하기
                    steps_per_epoch = TRAIN_STEP,
                    validation_steps = VALID_STEP,
                    )
# Out:
# Epoch 1/20
# 133/133 [==============================] - 315s 2s/step - loss: 0.4530 - acc: 0.8751 - val_loss: 2.2689 - val_acc: 0.1172
# Epoch 2/20
# 133/133 [==============================] - 289s 2s/step - loss: 0.1293 - acc: 0.9584 - val_loss: 4.0379 - val_acc: 0.1289
# Epoch 3/20
# 133/133 [==============================] - 244s 2s/step - loss: 0.0793 - acc: 0.9745 - val_loss: 2.0419 - val_acc: 0.3711
# Epoch 4/20
# 133/133 [==============================] - 280s 2s/step - loss: 0.0952 - acc: 0.9678 - val_loss: 0.5749 - val_acc: 0.7930
# Epoch 5/20
# 133/133 [==============================] - 237s 2s/step - loss: 0.0494 - acc: 0.9820 - val_loss: 0.2707 - val_acc: 0.8906
# Epoch 6/20
# 133/133 [==============================] - 236s 2s/step - loss: 0.0495 - acc: 0.9858 - val_loss: 0.0120 - val_acc: 1.0000
# Epoch 7/20
# 133/133 [==============================] - 229s 2s/step - loss: 0.0461 - acc: 0.9877 - val_loss: 0.0773 - val_acc: 0.9805
# Epoch 8/20
# 133/133 [==============================] - 227s 2s/step - loss: 0.0277 - acc: 0.9905 - val_loss: 1.4105 - val_acc: 0.6797
# Epoch 9/20
# 133/133 [==============================] - 233s 2s/step - loss: 0.0265 - acc: 0.9915 - val_loss: 0.1203 - val_acc: 0.9414
# Epoch 10/20
# 129/133 [============================>.] - ETA: 5s - loss: 0.0245 - acc: 0.9932
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-2cf3e2d0c35b> in <module>()
#      16                     # 계산하기
#      17                     steps_per_epoch = TRAIN_STEP,
# ---> 18                     validation_steps = VALID_STEP,
#      19                     )
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1387               logs = tmp_logs  # No error, now safe to assign to logs.
#    1388               end_step = step + data_handler.step_increment
# -> 1389               callbacks.on_train_batch_end(end_step, logs)
#    1390               if self.stop_training:
#    1391                 break
#
# /usr/local/lib/python3.7/dist-packages/keras/callbacks.py in on_train_batch_end(self, batch, logs)
#     436     """
#     437     if self._should_call_train_batch_hooks:
# --> 438       self._call_batch_hook(ModeKeys.TRAIN, 'end', batch, logs=logs)
#     439
#     440   def on_test_batch_begin(self, batch, logs=None):
#
# /usr/local/lib/python3.7/dist-packages/keras/callbacks.py in _call_batch_hook(self, mode, hook, batch, logs)
#     295       self._call_batch_begin_hook(mode, batch, logs)
#     296     elif hook == 'end':
# --> 297       self._call_batch_end_hook(mode, batch, logs)
#     298     else:
#     299       raise ValueError(
#
# /usr/local/lib/python3.7/dist-packages/keras/callbacks.py in _call_batch_end_hook(self, mode, batch, logs)
#     316       self._batch_times.append(batch_time)
#     317
# --> 318     self._call_batch_hook_helper(hook_name, batch, logs)
#     319
#     320     if len(self._batch_times) >= self._num_batches_for_timing_check:
#
# /usr/local/lib/python3.7/dist-packages/keras/callbacks.py in _call_batch_hook_helper(self, hook_name, batch, logs)
#     354     for callback in self.callbacks:
#     355       hook = getattr(callback, hook_name)
# --> 356       hook(batch, logs)
#     357
#     358     if self._check_timing:
#
# /usr/local/lib/python3.7/dist-packages/keras/callbacks.py in on_train_batch_end(self, batch, logs)
#    1032
#    1033   def on_train_batch_end(self, batch, logs=None):
# -> 1034     self._batch_update_progbar(batch, logs)
#    1035
#    1036   def on_test_batch_end(self, batch, logs=None):
#
# /usr/local/lib/python3.7/dist-packages/keras/callbacks.py in _batch_update_progbar(self, batch, logs)
#    1104     if self.verbose == 1:
#    1105       # Only block async when verbose = 1.
# -> 1106       logs = tf_utils.sync_to_numpy_or_python_type(logs)
#    1107       self.progbar.update(self.seen, list(logs.items()), finalize=False)
#    1108
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/tf_utils.py in sync_to_numpy_or_python_type(tensors)
#     561     return t.item() if np.ndim(t) == 0 else t
#     562
# --> 563   return tf.nest.map_structure(_to_single_numpy_or_python_type, tensors)
#     564
#     565
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/nest.py in map_structure(func, *structure, **kwargs)
#     912
#     913   return pack_sequence_as(
# --> 914       structure[0], [func(*x) for x in entries],
#     915       expand_composites=expand_composites)
#     916
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/nest.py in <listcomp>(.0)
#     912
#     913   return pack_sequence_as(
# --> 914       structure[0], [func(*x) for x in entries],
#     915       expand_composites=expand_composites)
#     916
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/tf_utils.py in _to_single_numpy_or_python_type(t)
#     555     # Don't turn ragged or sparse tensors to NumPy.
#     556     if isinstance(t, tf.Tensor):
# --> 557       t = t.numpy()
#     558     # Strings, ragged and sparse tensors don't have .item(). Return them as-is.
#     559     if not isinstance(t, (np.ndarray, np.generic)):
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/ops.py in numpy(self)
#    1221     """
#    1222     # TODO(slebedev): Consider avoiding a copy for non-CPU or remote tensors.
# -> 1223     maybe_arr = self._numpy()  # pylint: disable=protected-access
#    1224     return maybe_arr.copy() if isinstance(maybe_arr, np.ndarray) else maybe_arr
#    1225
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/ops.py in _numpy(self)
#    1187   def _numpy(self):
#    1188     try:
# -> 1189       return self._numpy_internal()
#    1190     except core._NotOkStatusException as e:  # pylint: disable=protected-access
#    1191       raise core._status_to_exception(e) from None  # pylint: disable=protected-access
#
# KeyboardInterrupt:

# %% [markdown]
# #추론

# %%
my_model = models.load_model('/content/drive/MyDrive/eff_landmark/model.h5')
my_model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 180, 180, 3)]     0
#
#  efficientnetb7 (Functional)  (None, 6, 6, 2560)       64097687
#
#  global_average_pooling2d (G  (None, 2560)             0
#  lobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 2560)              0
#
#  dense (Dense)               (None, 8)                 20488
#
# =================================================================
# Total params: 64,118,175
# Trainable params: 63,807,448
# Non-trainable params: 310,727
# _________________________________________________________________

# %%
my_model.evaluate(valid_ds)
# Out:
# 33/33 [==============================] - 46s 1s/step - loss: 0.0119 - acc: 1.0000
# [0.01189019437879324, 1.0]

# %%
class_dict = valid_ds.class_indices
class_dict = {value:key for key, value in class_dict.items()}
class_dict
# Out:
# {0: '골드원호텔&스위트',
#  1: '골든튤립제주성산호텔',
#  2: '공천포구',
#  3: '곽지과물해변',
#  4: '곽지해수욕장',
#  5: '관덕정',
#  6: '교래 삼다수마을',
#  7: '교래자연휴양림'}

# %%
import matplotlib.pyplot as plt
import numpy as np

for imgs, labels in valid_ds:
  preds = my_model.predict(imgs)
  print(imgs.shape, labels.shape, preds.shape)

  for i in range(BATCH_SIZE):
    label = np.argmax(labels[i])
    pred = np.argmax(preds[i])
    if label==pred: result='정답!'
    else: result = '오답!'
    print(f'[{result}] "{class_dict[label]}" 을 "{class_dict[pred]}" 라고 {preds[i][pred]*100:.2f}% 확률로 예측하였습니다. ')
    plt.xticks([]);plt.yticks([])
    plt.imshow(imgs[i])
    plt.show()
  break
# Out:
# (8, 180, 180, 3) (8, 8) (8, 8)
# [정답!] "교래 삼다수마을" 을 "교래 삼다수마을" 라고 99.98% 확률로 예측하였습니다.
# [정답!] "곽지해수욕장" 을 "곽지해수욕장" 라고 100.00% 확률로 예측하였습니다.
# [정답!] "골드원호텔&스위트" 을 "골드원호텔&스위트" 라고 98.63% 확률로 예측하였습니다.
# [정답!] "골든튤립제주성산호텔" 을 "골든튤립제주성산호텔" 라고 100.00% 확률로 예측하였습니다.
# [정답!] "곽지과물해변" 을 "곽지과물해변" 라고 87.29% 확률로 예측하였습니다.
# [정답!] "교래자연휴양림" 을 "교래자연휴양림" 라고 99.89% 확률로 예측하였습니다.
# [정답!] "곽지해수욕장" 을 "곽지해수욕장" 라고 100.00% 확률로 예측하였습니다.
# [정답!] "곽지해수욕장" 을 "곽지해수욕장" 라고 99.94% 확률로 예측하였습니다.
