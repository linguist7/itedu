# %% [markdown]
# # 5-2.클래스: 클래스 더 다루기
# ---
# * 날짜:
# * 이름:

# %% [markdown]
# ## 개념정리
# ---

# %% [markdown]
# 저번 시간까지 배운 클래스 내용만으로도 충분히 클래스를 만들고 코드를 읽을 수 있습니다. 하지만 클래스에는 더 많은 유용한 기능들이 있습니다. 이를 이해하면 더 쉽고 유용하게 파이썬 코드를 작성할 수 있을 겁니다.

# %% [markdown]
# ###**(1) 매직 메소드**
#
# 매직 메소드는 파이썬에서 미리 정의해 놓은 메소드입니다. 이 메소드들은 각각이 지니는 고유 기능들이 있습니다.
#
# 지난 시간에 배운 `__init__`이라는 메소드 또한 매직 메소드의 일종입니다.
#
# 매직메소드 개수는 꽤 많고 각각 복잡한 일들을 하기 때문에 이번시간에 다 다루지는 않겠습니다. 다만 자주 쓰이는 몇가지 메소드를 함께 보도록 합니다.

# %% [markdown]
# #### **클래스의 덧셈**
#
# 특정 숫자를 소개하는 클래스 `Mynumber()`를 아래와 같이 정의해 봅시다.
#
# ```
# class MyNumber():
#   def __init__(self, num):
#     self.num = num
#   def intro(self):
#     print(f"my num is {self.num}")
# ```

# %%
class MyNumber():
  def __init__(self, num):
    self.num = num
  def intro(self):
    print(f"my num is {self.num}")

# %% [markdown]
# * `num` 값이 2인 인스턴스 생성
#
# ```
# a = MyNumber(2)
# a.intro()
# ```

# %%
a = MyNumber(2)
a.intro()
# Out:
# my num is 2

# %% [markdown]
# * `num` 값이 5인 인스턴스 생성
#
# ```
# b = MyNumber(5)
# b.intro()
# ```

# %%
b = MyNumber(5)
b.intro()
# Out:
# my num is 5

# %% [markdown]
# * 인스턴스끼리 더하기
#
# 인스턴스 `a`와 `b`를 더하고 싶습니다. 더해서 7이란 값이 나오면 좋겠네요. 한번 덧셈을 해봅시다.
#
# ```
# a+b
# ```

# %%
a+b
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-ca730b97bf8a> in <module>()
# ----> 1 a+b
#
# TypeError: unsupported operand type(s) for +: 'MyNumber' and 'MyNumber'

# %% [markdown]
# 에러가 뜹니다. 인스턴스가 덧셈이 가능하게 하도록 하려면 `__add__` 메소드를 이용해야 합니다.
#
# `+`으로 연결된 다른 인스턴스는 `other`로 자동 연결됩니다. `+`를 함으로써 우리는 인스턴스의 `num`값을 더하고 싶으니 이를 `return`해 주면 됩니다.
#
# ```
# class MyNumber():
#   def __init__(self, num):
#     self.num = num
#   def intro(self):
#     print(f"my num is {self.num}")
#
#   def __add__(self, other):
#     return self.num+other.num
# ```

# %%
class MyNumber():
  def __init__(self, num):
    self.num = num
  def intro(self):
    print(f"my num is {self.num}")

  def add(self, other):
    return self.num+other.num

  def mul(self, other):
    return self.num*other.num

  def sub(self, other):
    return self.num-other.num  

  def div(self, other):
    return self.num/other.num

# %% [markdown]
# * `num` 값이 2인 인스턴스 생성
#
# ```
# a = MyNumber(2)
# a.intro()
# ```

# %%
a = MyNumber(2)
a.intro()
# Out:
# my num is 2

# %%
a.num
# Out:
# 2

# %% [markdown]
# * `num` 값이 5인 인스턴스 생성
#
# ```
# b = MyNumber(5)
# b.intro()
# ```

# %%
b = MyNumber(5)
b.intro()
# Out:
# my num is 5

# %% [markdown]
# * 인스턴스끼리 더하기
#
# 인스턴스 `a`와 `b`를 더하고 싶습니다. 더해서 7이란 값이 나오면 좋겠네요. 한번 덧셈을 해봅시다.
#
# ```
# a+b
# ```

# %%
a.add(b)
# Out:
# 7

# %% [markdown]
# 이제 7이란 값이 제대로 나오는 것을 볼 수 있습니다.

# %% [markdown]
# #### **클래스의 문자**
#
# * `__str__`
#
# 이 메소드는 인스턴스의 출력을 지정해 줍니다. 위에서 정의한 인스턴스 a 를 출력해보겠습니다.
#
# ```
# print(a)
# ```

# %%
print(a)
# Out:
# <__main__.MyNumber object at 0x7f35bf3cdfd0>

# %% [markdown]
# 이번에는 클래스 안에 `__str__` 메서드를 추가해 보겠습니다. 현재 `intro` 메서드가 출력을 수행하고 있어서 기능이 겹치네요. 이를 바꾸도록 하겠습니다.
#
# ```
# class MyNumber():
#   def __init__(self, num):
#     self.num = num
#   def __str__(self):
#     return f"my num is {self.num}"
#   def __add__(self, other):
#     return self.num+other.num
# ```

# %%
class MyNumber():
  def __init__(self, num):
    self.num = num
  def intro(self):
    return f"my num is {self.num}"
  def add(self, other):
    return self.num+other.num

# %% [markdown]
# * `num` 값이 2인 인스턴스 생성하고 출력하기
#
# ```
# a = MyNumber(2)
# a.intro()
# ```

# %%
a = MyNumber(2)
a.intro()
# Out:
# 'my num is 2'

# %% [markdown]
# ### **(2) 상속**

# %% [markdown]
# #### **상속이란**
#
# 상속이란 이미 만들어진 클래스를 그대로 받아와 사용할 수 있을 뿐 아니 세부적으로 변경할 수도 있게 하는 것입니다.
#
# 이 때 상속받아온 상위 클래스를 부모 클래스, 하위클래스를 자식 클래스라 합니다.
#
# 위에서 만든 `MyNumber`클래스를 상속받아 봅시다. 상속 받기 위해서는 클래스 이름을 정의할 때 상속받을 클래스를 작성해 줍니다.
#
# ```
#
# class EvenNumber(MyNumber): # 상속받아오기
#   def __str__(self): # __str__ 메서드는 변경하기
#     return f"my num is {self.num}. and it is even."
#
# class OddNumber(MyNumber):
#   def __str__(self): # __str__ 메서드는 변경하기
#     return f"my num is {self.num}. and it is odd."
#
# ```

# %%
class EvenNumber(MyNumber): # 상속받아오기
  def even(self): # __str__ 메서드는 변경하기
    return f"my num is {self.num}. and it is even."

class OddNumber(MyNumber):
  def odd(self): # __str__ 메서드는 변경하기
    return f"my num is {self.num}. and it is odd."

# %% [markdown]
# * 인스턴스 생성

# %%
even = EvenNumber(2)
odd = OddNumber(3)

# %% [markdown]
# * 인스턴스  출력하기
#
# 같은 부모에게서 상속 받아 왔지만 `__str__`의 반환값이 다르기 때문에 출력이 다른 것을 확인할 수 있습니다.
#
# ```
# print(even)
# print(odd)
# ```

# %%
print(even)
print(odd)
# Out:
# <__main__.EvenNumber object at 0x7f35bf3f7f10>
# <__main__.OddNumber object at 0x7f35bf3f7cd0>

# %% [markdown]
# * 또한 부모클래스에 있던 `__add__` 메소드도 사용할 수 있습니다.
#
# ```
# even+odd
# ```

# %%
even.add(odd)
# Out:
# 5

# %%
import random

# %%
56
78
#로또번호 6개

random_num = []
for i in range(0, 6):
  random_num.append(random.randint(1, 45))

#선택번호 6개
choice_num = []
def lotto():
  for i in range(1, 7):
    a= input(f'{i}번째 숫자 입력(1-45):')
    choice_num.append(a)

lotto()

#정답비교
answer=0
for i, j in zip(choice_num, random_num):
  if i in str(j):
    answer +=1

print(f'{answer}개 맞춤')
# Out:
# 1번째 숫자 입력(1-45):1
# 2번째 숫자 입력(1-45):2
# 3번째 숫자 입력(1-45):3
# 4번째 숫자 입력(1-45):4
# 5번째 숫자 입력(1-45):
# 6번째 숫자 입력(1-45):8
# 1개 맞춤

# %%
7
