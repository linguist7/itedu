# %% [markdown]
# # 1-3. 사용자 입출력
# ---
# * 날짜:
# * 이름:

# %% [markdown]
# ## 개념정리
# ---
#
#
# 사용자에게서 변수를 얻어서 그에 맞는 프로그램을 짜고 싶다면 입력기능이 필요합니다. 또한 원하는 기능을 실행 후 결과물을 확인하고 싶다면 출력기능이 필요합니다. 이번시간에서는 파이썬의 입출력기능을 알아보도록 합니다.

# %% [markdown]
# ### **(1) 입력**

# %% [markdown]
# 사용자의 입력을 파이썬의 `input()` 함수를 이용해서 받을 수 있습니다. 아래 코드를 실행하면 사용자의 입력을 받는 창이 나타납니다.
#
# ```
# input()
# ```

# %%
input()
# Out:
# python
# 'python'

# %% [markdown]
# #### **설명 추가**
#
# 입력을 받을 때 설명을 추가해주고 싶다면 아래와 같이 함수의 괄호 안에 문자열을 삽입합니다.
# ```
# input("이름을 입력하세요:")
# ```

# %%
input('이름을 입력하세요')
# Out:
# 이름을 입력하세요안창덕
# '안창덕'

# %% [markdown]
# #### **바인딩**
#
# `input()` 함수로 받은 값을 바인딩 하여 저장할 수 있습니다.
# ```
# my_name = input('이름을 입력하세요:')
# ```

# %%
my_name = input('이름을 입력하세요:')
# Out:
# 이름을 입력하세요:안창덕

# %% [markdown]
# 위에서 선언한 `my_name`을 확인해 봅시다.
#
# ```
# my_name, type(my_name)
# ```

# %%
my_name, type(my_name)
# Out:
# ('안창덕', str)

# %% [markdown]
# `input()` 함수로 바인딩한 값은 모두 `문자열(str)` 임을 주의합니다.
# ```
# my_age = input("나이를 입력하세요: ")
# type(my_age)
# ```

# %%
my_age = input("나이를 입력하세요: ")
type(my_age)
# Out:
# 나이를 입력하세요: 33
# str

# %% [markdown]
# ### **(2) 출력**
# ---

# %% [markdown]
# * `print()` : 원하는 값을 출력 할 수 있습니다.
#
# ```
# print(2)
# ```

# %%
print(2)
# Out:
# 2

# %% [markdown]
# 문자 또한 출력 할 수 있습니다.
#
# ```
# print("hello")
# print('world')
# ```

# %%
print(my_name)
print(my_age)
# Out:
# 안창덕
# 33

# %% [markdown]
# 여러개의 인풋을 함께 쉼표(  `,`  )를 이용해 출력할 수 있습니다.
#
# ```
# print(5,  "apples")
# ```

# %%
print(5, "apples", "사과")
# Out:
# 5 apples 사과

# %% [markdown]
# #### **옵션**
#
# * `sep` : 출력하는 값들 사이를 어떤 값으로 채울지 지정할 수 있습니다. 디폴트 값은 스페이스(' ') 입니다.
#
# ```
# print("Hello", "world", 1, 2, 3, sep='*')
# ```

# %%
print("Hello", "world", 1, 2, 3, sep=' ')
# Out:
# Hello world 1 2 3

# %% [markdown]
# * `end` : 문장이 끝날 때 어떤 문자로 끝날 지 지정해 줍니다. 기본값은 줄바꿈(`\`) 입니다.
#
# ```
# print("Hello", "world", 1, 2, 3, end='*')
# ```

# %%
print("Hello", "world", 1, 2, 3,)
print("abc")
# Out:
# Hello world 1 2 3
# abc

# %% [markdown]
# ## 문제풀이
# ---

# %% [markdown]
# **예제 01**
#
# 아래와 같이 직업을 입력하는 코드를 작성하세요
#
# ```
# >> 직업을 입력하세요:
# ```

# %%
input("직업을 입력하세요:" )
# Out:
# 직업을 입력하세요:학생
# '학생'

# %% [markdown]
# **예제 02**
#
# 아래와 같이 직업을 입력하면 소개글을 출력하는 코드를 작성하세요
#
#
# ```
# >> 직업을 입력하세요:
# >> 당신의 직업은 강사 입니다.
# ```

# %%
input("직업을 입력하세요:")
print("당신의 직업은 강사 입니다.")
# Out:
# 직업을 입력하세요:강사
# 당신의 직업은 강사 입니다.

# %% [markdown]
# **예제 03**
#
# 아래와 같이 직업을 입력하면 소개글을 출력하는 코드를 작성하세요
#
# ```
# >> 직업을 입력하세요:
# >> 당신의 직업은 '강사' 입니다.
# ```

# %%
input("직업을 입력하세요:")
print("당신의 직업은 '강사' 입니다.")
# Out:
# 직업을 입력하세요:강사
# 당신의 직업은 '강사' 입니다.

# %% [markdown]
# **예제 04**
#
# 아래와 같이 좋아하는 숫자를 출력하는 코드를 작성하세요
#
# ```
# >> 내가 좋아하는 숫자: 7
# >> 내가 좋아하는 숫자는 7 이다.
# ```

# %%
input("내가 좋아하는 숫자:")
print("내가 좋아하는 숫자는 7이다.")
# Out:
# 내가 좋아하는 숫자:7
# 내가 좋아하는 숫자는 7이다.

# %% [markdown]
# **예제 04**
#
# 아래와 같이 코드를 작성하였는데 오류가 떴습니다. 이유를 설명하세요.
#
# ```
# my_num = input("내가 좋아하는 숫자: ")
# print(my_num+10)
# ```

# %%
my_num = input("내가 좋아하는 숫자: ") #input 은 자료형이 문자열이기 때문에 수식이 적용되지 않는다.
print(my_num+10)
# Out:
# 내가 좋아하는 숫자: 7
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-5be186080275> in <module>()
#       1 my_num = input("내가 좋아하는 숫자: ")
# ----> 2 print(my_num+10)
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# **예제 05**
#
# 화면에 아래 문장을 출력하세요.
#
# ```
# nice day!
# ```

# %%
print("nice day!")
# Out:
# nice day!

# %% [markdown]
# **예제 06**
#
# 아래 출력이 나오도록 `#코드작성` 부분을 채워 넣으세요  (코드 한줄로 완성하세요)
#
# ```
# >> w1 = "hello"
# >> w2 = "python"
# >> w3 = 2
# >> #코드작성
# >> hello! python 2
# ```

# %%
w1 = "hello"
w2 = "python"
w3 = 2
print(w1, w2, w3, sep=' ')
# Out:
# hello python 2

# %% [markdown]
# **예제 07**
#
# 아래 출력이 나오도록 `#코드작성` 부분을 채워 넣으세요  (코드 한줄로 완성하세요)
#
# ```
# >> w1 = '나의'
# >> w2 = '살던'
# >> w3 = '고향은'
# >> #코드작성
# 나의~살던~고향은~
# ```

# %%
w1 = '나의'
w2 = '살던'
w3 = '고향은'
print(w1, w2, w3, sep='~', end='~')
# Out:
# 나의~살던~고향은~

# %% [markdown]
# **예제 08**
#
# 아래 출력이 나오도록 `#코드작성` 부분을 채워 넣으세요
#
# ```
# >> w1 = '나의'
# >> w2 = '살던'
# >> w3 = '고향은'
# >> print(w1, end=#코드작성)
# >> print(w2, end=#코드작성)
# >> print(w3, end=#코드작성)
# 나의 살던 고향은~
# ```

# %%
print(w1, end=' ')
print(w2, end=' ')
print(w3, end='~')
# Out:
# 나의 살던 고향은~

# %% [markdown]
# **예제 09**
#
# 아래 출력이 나오도록 `#코드작성` 부분을 채워 넣으세요  (코드 한줄로 완성하세요)
#
# ```
# >> w1 = '나의'
# >> w2 = '살던'
# >> w3 = '고향은'
# >> #코드작성
# 나의**살던**고향은
# ```

# %%
w1 = '나의'
w2 = '살던'
w3 = '고향은'
print(w1, w2, w3, sep='**')
# Out:
# 나의**살던**고향은

# %% [markdown]
# **예제 10**
#
# 아래 출력이 나오도록  `#코드작성` 부분을 채워 넣으세요 (코드 한줄로 완성하세요)
#
# ```
# >> w1 = '나의'
# >> w2 = '살던'
# >> w3 = '고향은'
# >> #코드작성
# 나의
# 살던
# 고향은
# ```

# %%
w1 = '나의'
w2 = '살던'
w3 = '고향은'
print(w1)
print(w2)
print(w3)
# Out:
# 나의
# 살던
# 고향은

# %% [markdown]
# **예제 11**
#
# 아래 코드의 결과를 예측하고 그 이유를 해설하세요
#
# ```
# print('hello python")
# ```

# %%
print('hello python") #문자형일 때 따옴표를 통일하지 않으면 오류가 난다.
# Out:
#   File "<ipython-input-42-54241112988d>", line 1
#     print('hello python") #문자형일 때 따옴표를 통일하지 않으면 오류가 난다.
#                                                        ^
# SyntaxError: EOL while scanning string literal

# %% [markdown]
# **예제 12**
#
# 아래와 같이 이름과 나이를 `input()`으로 받고 소개글을 출력하는 코드를 작성하세요
#
# ```
# >> 이름 : 홍길동
# >> 나이: 20
# 반갑습니다. 20살 홍길동 이라고 합니다. 잘 부탁드립니다!
# ```

# %%
name = input('이름 :')
age = input('나이: ')
print('반갑습니다. 20살 홍길동 이라고 합니다. 잘 부탁드립니다!')
# Out:
# 이름 :홍길동
# 나이: 20
# 반갑습니다. 20살 홍길동 이라고 합니다. 잘 부탁드립니다!

# %% [markdown]
# **예제 13**
#
# 아래와 같이 특정 메뉴를 고르는 코드를 작성하세요
#
# ```
# >> 아메리카노    라떼   에스프레소
# >> 메뉴를 선택하세요 : 라떼
# 라떼를 선택하였습니다.
# ```

# %%
menu = input('메뉴를 선택하세요:')
print(menu, '를 선택하였습니다.')
# Out:
# 메뉴를 선택하세요:라떼
# 라떼 를 선택하였습니다.

# %% [markdown]
# **예제 14**
#
# 아래와 같이 휴대폰 번호를 입력하면 전체 번호를 출력하는 코드를 작성하세요
#
# ```
# >> 휴대폰 앞자리 : 010
# >> 휴대폰 중간자리: 1111
# >> 휴대폰 뒷자리: 1111
# 제 번호는 010-1111-1111 입니다.
# ```

# %%
front = input('휴대폰 앞자리:')
middle = input('휴대폰 중간자리:')
back = input('휴대폰 뒷자리:')
print('제 번호는', front, midle, back, '입니다.')
# Out:
# 휴대폰 앞자리:010
# 휴대폰 중간자리:5755
# 휴대폰 뒷자리:7914
# 제 번호는 010 5755 7914 입니다.

# %% [markdown]
# **예제 15**
#
# 아래와 같이 두개의 값을 받아서 더하고 뺀 값을 알려주는 코드를 작성하세요
#
# ```
# >> 첫번째 숫자를 입력하세요: 2
# >> 두번째 숫자를 입력하세요: 3
# 두개의 숫자를 더한 값은 5 이고 뺀값은 -1 입니다.
# ```

# %%
a = input('첫번째 숫자를 입력하세요:')
b = input('두번째 숫자를 입력하세요:')
print('두개의 숫자를 더한 값은', int(a)+int(b), '이고 뺀값은', int(a)-int(b), '입니다.') #input은 문자열이어서 수식이 적용되지 않아 오류가 뜸
# Out:
# 첫번째 숫자를 입력하세요:2
# 두번째 숫자를 입력하세요:3
# 두개의 숫자를 더한 값은 5 이고 뺀값은 -1 입니다.

# %%
3
