# %% [markdown]
# # 2-1.파이썬의 자료형:숫자
# ---
# * 날짜:
# * 이름:

# %% [markdown]
# ## 개념정리
# ---
#
#
# 코드를 작성하면서 우리는 다양한 데이터 자료형을 접하게 됩니다. 그 중 수치 자료형은 개수, 가격, 날짜 등 여러가지 데이터를 효과적으로 처리할 수 있습니다. 수치 자료형에 대해 알아보고 데이터 타입이 수치 자료형일 때 어떤 부가적인 연산들을 수행할 수 있는지 알아보도록 합니다.

# %% [markdown]
# ### (1) 수치자료형의 종류

# %% [markdown]
# #### **정수 `int`**
# 정수형 자료형은 `int` 로 표시 됩니다. -1,-2, ... 0 , 1, 2 ,...  등 정수값을 나타냅니다.
# ```
# num = 2
# print(num, type(num))
# ```

# %%
num = 2
print(num, type(num))
# Out:
# 2 <class 'int'>

# %% [markdown]
# #### **실수 `float`**
# 실수값은 `float`으로 표히 됩니다. 3.0, 3.1 , ... 등 실수값을 나타냅니다.
# ```
# num = -0.2
# print(num, type(num))
# ```

# %%
num = -0.2
print(num, type(num))
# Out:
# -0.2 <class 'float'>

# %% [markdown]
# #### **복소수 `complex`**
# 복소수는 제곱했을 때 음수가 되는 수입니다. 아래와 같이 정의할 수 있습니다.
# ```
# num = 1+4j
# print(num, type(num))
# ```

# %%
num = 1+4j
print(num, type(num))
# Out:
# (1+4j) <class 'complex'>

# %% [markdown]
# 복소수 자료형 경우  파이썬 내장 함수를 통해 실수값, 허수값, 컬례 복소수 등을 알 수 있습니다.
#
# * `.real()` : 복소수의 실수값을 확인합니다.
#
# ```
# print(num.real)
# ```

# %%
print(num.real)
# Out:
# 1.0

# %% [markdown]
# * `.image()`: 복소수의 허수값을 확인합니다.
#
# ```
# print(num.imag) # 허수값
# ```

# %%
print(num.imag)
# Out:
# 4.0

# %% [markdown]
# * `.conjugate()`: 복소수의 컬례복소수를 확인합니다.
#
# ```
# print(num.conjugate()) # 컬례복소수
# ```

# %%
print(num.conjugate())
# Out:
# (1-4j)

# %% [markdown]
# ### (2) 수치자료형의 타입 변환
#
# 수치자료형의 타입을 변환 할 수 있습니다. 아래와 같이 `a`를 값 1인 정수값으로 정의합시다.
#
# ```
# a=1
# a, type(a)
# ```

# %%
a=1
a, type(a)
# Out:
# (1, int)

# %% [markdown]
# 현재 `int` 타입인 값을 `float`으로 변환해보도록 합시다.
#
# ```
# a = float(a)
# print(a, type(a))
# ```

# %%
a = float(a)
print(a, type(a))
# Out:
# 1.0 <class 'float'>

# %% [markdown]
# 다시 `int` 로 변환 해봅시다.
#
# ```
# a = int(a)
# print(a, type(a))
# ```

# %%
a = int(a)
print(a, type(a))
# Out:
# 1 <class 'int'>

# %% [markdown]
# 참고로 문자형과도 변환이 가능합니다.
#
# ```
# a = str(a)
# print(a, type(a))
# ```

# %%
a = str(a)
print(a, type(a))
# Out:
# 1 <class 'str'>

# %% [markdown]
# ### (3) 산술연산자
#
# 수치 자료형은 각종 산술연산이 가능합니다. 우리가 일반적으로 쓰는 덧셈, 뺄셈, 곱셉, 나눈셈을 수행해 보겠습니다. 아래 코드를 따라 쓰고 무엇이 나오는지 예측해 봅니다

# %% [markdown]
# *  `+` 더하기
#
# ```
# 2+2
# ```

# %% [markdown]
# *   `-` 빼기
#
# ```
# 2-2
# ```

# %% [markdown]
# *  `*` 곱하기
#
# ```
# 2*2
# ```

# %% [markdown]
# *  `**` 제곱
#
# ```
# 2**2
# ```

# %%
2**4
# Out:
# 16

# %% [markdown]
# *  `/` 나누기
#
# ```
# 2/2
# ```

# %%
3/4
# Out:
# 0.75

# %% [markdown]
# *  `//` 몫
#
# ```
# 2//2
# ```

# %%
4//3
# Out:
# 1

# %% [markdown]
# * `%` 나머지
#
# ```
# 2%2
# ```

# %%
3%2
# Out:
# 1

# %% [markdown]
# ### **(4) 할당 연산자**
#
# 할당연산자는 값을 변수에 바로 할당하는 연산자 입니다. 할당이란 것은 바인딩과 동일한 의미입니다. 따라서 `=` 이 기호는 할당연산자 라고 할 수 있습니다. 그러나 `=` 말고도 할당연산자는 몇개 더 있습니다.
#
# | 기호 | 뜻 |
# |--|--|
# |`+=`| 더한 후 대입 |
# |`-=`| 뺀 후  대입 |
# |`*=`| 곱한 후 대입 |
# |`**=`| 제곱 후 대입 |
# |`/=`| 나눈 후 대입 |
# |`//=`| 나눈 후 몫을 대입 |
# |`%=`| 나눈 후 나머지 대입 |

# %% [markdown]
# #### **더한 후 대입하기**
#
#
# * `+=`
#
# ```
# a = 5
# b = 2
# a += b # 할당연산자 사용  `a = a+b` 과 동일
# print(a)
# ```

# %% [markdown]
# #### **뺀 후 대입하기**
#
# * `-=`
#
# ```
# a = 5
# b = 2
# a -= b # 할당연산자 사용  `a = a-b` 과 동일
# print(a)
# ```

# %%
a = 5
b = 2
a -= 5
a
# Out:
# 0

# %% [markdown]
# #### **곱한 후 대입하기**
#
# * `*=`
#
# ```
# a = 5
# b = 2
# a *= b # 할당연산자 사용  `a = a*b` 과 동일
# print(a)
# ```

# %% [markdown]
# #### **제곱 후 대입하기**
#
# * `**=`
#
# ```
# a = 5
# b = 2
# a **= b # 할당연산자 사용  `a = a**b` 과 동일
# print(a)
# ```

# %% [markdown]
# #### **나눈 후 대입하기**
#
# * `/=`
#
# ```
# a = 5
# b = 2
# a /= b # 할당연산자 사용  `a = a/b` 과 동일
# print(a)
# ```

# %% [markdown]
# #### **나눈 후 몫을 대입하기**
#
# * `//=`
#
# ```
# a = 5
# b = 2
# a //= b # 할당연산자 사용  `a = a//b` 과 동일
# print(a)
# ```

# %% [markdown]
# ### 나눈 후 나머지를 대입하기
#
# * `%=`
#
# ```
# a = 5
# b = 2
# a %= b # 할당연산자 사용  `a = a%b` 과 동일
# print(a)
# ```

# %% [markdown]
# ## 문제풀이
# ---
#
# **예제 01**
#
# 아래 코드의 실행 결과를 예상하고 출력해보세요
#
# ```
# 2+5-3*5
# ```

# %%
2+5-3*5
# Out:
# -8

# %% [markdown]
# **예제 02**
#
# 아래 코드의 실행 결과를 예상하고 출력해보세요
# ```
# print(10/2)
# print(10%2)
# print(11%2)
# print(12%2)
# print(13%2)
# print(14%2)
# ```

# %%
print(10/2)
print(10%2)
print(11%2)
print(12%2)
print(13%2)
print(14%2)
# Out:
# 5.0
# 0
# 1
# 0
# 1
# 0

# %% [markdown]
# **예제 03**
#
# `예제 02` 를 기반으로 `int` 값중 짝수와 홀수를 판별하는 방법을 제안하세요

# %%
#짝수면 결과값이 0 홀수면 결과값이 1

# %% [markdown]
# **예제 04**
#
# 정수기가 월 30,000원에 무이자할부 5년 조건으로 판매되고 있습니다. 총 금액을 계산한 후 이를 화면에 출력해보세요. (변수사용하기)

# %%
a = 30000
b = a*60
b
# Out:
# 1800000

# %% [markdown]
# **예제 05**
#
# 변수가 아래와 같이 선언되어 있습니다. 각 변수들끼리 서로 더한 결과를 정리하세요
#
# ```
# a = 5
# b = 3.14
# c = 3 + 4j
# ```

# %%
a = 5 
b = 3.14 
c = 3 + 4j
a+b+c
# Out:
# (11.14+4j)

# %% [markdown]
# **예제 06**
#
# 아래 결과를 예측하세요
#
#
# ```
# a= 1
# a= a+1
# a= a**3
# print(a)
# ```

# %%
a= 1
a= a+1
a= a**3
print(a)
# Out:
# 8

# %% [markdown]
# **예제 07**
#
# 아래 결과를 예측하세요
#
#
# ```
# a= 1+3j
# b= a.real
# print(b%2)
# ```

# %%
a= 1+3j
b= a.real
print(b%2)
# Out:
# 1.0

# %% [markdown]
# **예제 08**
#
# 아래와 같이 주가와 주식개수를 인풋으로 받아 평가금액을 출력하는 코드를 작성하세요
#
# ```
# >> 주가: 10000
# >> 주식개수: 3
# 평가금액은 30000원 입니다.
# ```

# %%
a = input('주가:')
b = input('주가개수:')
print('평가금액은', int(a)*int(b), '원 입니다.')
# Out:
# 주가:10000
# 주가개수:3
# 평가금액은 30000 원 입니다.

# %% [markdown]
# 3**예제 09**
#
# 아래와 같이 복소수(complex)를 입력하면 실수값과 허수값, 실수값과 허수값을 알려주는 코드를 작성하세요.
#
# ```
# >> 복소수를 입력하세요: 1+5j
# 실수값은 1, 허수값은 5입니다.
# ```

# %%
a = input('복소수를입력하세요:')
b = complex(a)
c = b.real
d = b.imag
print('실수값은', c, '허수값은', d, '입니다.')
# Out:
# 복소수를입력하세요:1+5j
# 실수값은 1.0 허수값은 5.0 입니다.

# %% [markdown]
# **예제 10**
#
# 아래와 같이 정수(int)를 입력하면 제곱값과 세제곱값을 출력하는 코드를 작성하세요.
#
# ```
# >> 숫자를 입력하세요: 5
# 5의 제곱은 25이고 세제곱은 125 입니다.
# ```

# %%
a = input('숫자를 입력하세요:')
b = int(a)
print(b, '의 제곱은', b**2, '이고 세제곱은', b**3, '입니다.')
# Out:
# 숫자를 입력하세요:5
# 5 의 제곱은 25 이고 세제곱은 125 입니다.

# %% [markdown]
# **예제 11**
#
# 실수값(float)을 입력하면 실수값에 5를 더한 값을 출력하는 코드를 작성하세요
#
# ```
# >> 실수값을 입력하세요: 5.11
# 5를 더한 값은 10.11 입니다.
# ```

# %%
a = input('실수값을 입력하세요:')
b = float(a)
print(a, '를 더한 값은', b+5, '입니다.')
# Out:
# 실수값을 입력하세요:5.11
# 5.11 를 더한 값은 10.11 입니다.

# %% [markdown]
# **예제 12**
#
# 첫번째 숫자와 두번째 숫자를 입력하면 첫번째 숫자를 두번째 숫자로 나눈 몫과 나머지를 구하는 코드를 작성하세요
#
# ```
# >> 첫번째 숫자: 10
# >> 두번째 숫자: 3
# 10 나누기 3은 몫이 3이고 나머지는 1입니다.
# ```

# %%
a = input('첫번째 숫자:')
b = input('두번째 숫자:')
c = int(a)
d = int(b)
print(a, '나누기', b, '은 몫이', c//d, '이고 나머지는', c%d, '입니다.')
# Out:
# 첫번째 숫자:10
# 두번째 숫자:3
# 10 나누기 3 은 몫이 3 이고 나머지는 1 입니다.
